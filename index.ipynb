# %% [markdown]
# # Molecular dynamics simulation of a small protein using GROMACS

# %% [markdown]
#     authors  : Alessandra Villa (based on a Justin Lemkuhl tutorial see http://www.mdtutorials.com or Living J. Comp. Mol. Sci. 2018, 1, 5068).
#     goal     : learn step-by-step how to run a molecular dynamics simulation of a small protein using GROMACS
#     time     : 90 minutes
#     software : GROMACS 2023, python modules: numpy, matplotlib, re, nglviewer, md_traj, panda.
#     optional software: visualization software [VMD](https://www.ks.uiuc.edu/Research/vmd), Xmgrace plotting tool
#     tutorial source: tutorials.gromacs.org
#     version  : release - doi:10.5281/zenodo.11198376

# %% [markdown]
# # Preparations to run this notebook

# %%
# Change to the data directory
# Note that executing this command twice will result in an error you can ignore
# %cd kras_data
# Out:
# /home/thangavelucs/MD_Intro_Tutorial/md-intro-tutorial-main/kras_data

# %% [markdown]
# # Obtaining the input for a simulation

# %% [markdown]
# The starting point for each simulation is a molecular structure file. For this tutorial, we will utilize Factor Xa, a protein playing critical role in the formation of blood clots. The 3D structure is available from the RCSB website, https://www.rcsb.org/ with PDB code 1FJS. You can find the PDB file for the crystal structure in "input" directory as "1fjs.pdb".

# %% [markdown]
# Now we visualize the structure

# %%
import nglview as ng
view = ng.show_structure_file("hvr060-040_pub.pdb")
view
# click and drag to rotate, zoom with your mouseweel 
# for more infor on this viewer have a look at https://github.com/nglviewer/nglview
# Out:
# NGLWidget()

# %% [markdown]
# ## Cleaning the input structure

# %%
# !cat hvr060-040_pub.pdb
# Out:
# cat: hvr060-040_pub.pdb: No such file or directory

# %% [markdown]
# #Remove
# Once you've had a look at the molecule, strip out all the atoms that do not belong to the protein (e.i crystal waters, ligands, etc). To delete those atoms (labelled "HETATM" in the PDB file) and eventually their connectivity, either use a plain text editor like Notepad (Windows). Alternatively, you can use grep to delete these lines very easily:

# %%
#removing POPS molecules
# !grep -v POPS hvr060-040_pub.pdb > 1fjs_protein_tmp.pdb

# %%
# !grep -v CONECT 1fjs_protein_tmp.pdb > 1fjs_protein.pdb

# %%
#removing POPC molecules
# !grep -v POPC 1fjs_protein.pdb > 1fjs_protein_tmp2.pdb

# %%
# !grep -v CONECT 1fjs_protein_tmp2.pdb > 1fjs_protein.pdb

# %%
#removing phenylalanine residues
# !grep -v CYF 1fjs_protein.pdb > 1fjs_protein_tmp3.pdb

# %%
# !grep -v CONECT 1fjs_protein_tmp3.pdb > 1fjs_protein.pdb

# %%
# !cat 1fjs_protein.pdb
# Out:
# cat: 1fjs_protein.pdb: No such file or directory

# %% [markdown]
# View the cleaned structure

# %%
import nglview as ng
view = ng.show_structure_file("1fjs_protein.pdb")
view
# click and drag to rotate, zoom with your mouseweel 
# for more infor on this viewer have a look at https://github.com/nglviewer/nglview
# Out:
# NGLWidget()

# %% [markdown]
# Note *Such a procedure is not universally appropriate (e.g., the case of a tightly bound ligand or otherwise functional active-site water molecule).*

# %%
# !grep MISSING hvr060-040_pub.pdb

# %% [markdown]
# ## Generating a topology

# %% [markdown]
# Now we have verified the PDB file, its ready to be input into GROMACS (see <a href=http://manual.gromacs.org/current/index.html> GROMACS documentation </a>).
# We use the [`gmx pdb2gmx`](https://manual.gromacs.org/current/onlinehelp/gmx-pdb2gmx.html) gromacs tool to generate three files:
#
# * The topology for the molecule.
# * A position restraint file.
# * A post-processed structure file.
#
# The topology (topol.top by default) contains all the information necessary to define the molecule within a simulation including nonbonded parameters (atom types and charges) as well as bonded parameters (bonds, angles, dihedrals and atom connectivity).

# %% [markdown]
# Note *Incomplete internal sequences or any amino acid residues that have missing atoms will cause `gmx pdb2gmx` to fail. `gmx pdb2gmx` cannot generate topologies for arbitrary molecules, just the residues defined by the force field(in the *.rtp files ( proteins, nucleic acids, and a some cofactors, like NAD(H) and ATP).*

# %%
# !more hvr060-040_pub.gro

# %% [markdown]
# Execute `gmx pdb2gmx` by issuing the following command:

# %%
#a gro file is already provided (see above)
# !gmx pdb2gmx -f 1fjs_protein.pdb -o 1fjs_processed.gro -water tip3p -ff "CHARMM36"
# Out:
#                :-) GROMACS - gmx pdb2gmx, 2023.3-conda_forge (-:
#
# Executable:   /home/thangavelucs/anaconda3/envs/md-intro-tutorial/bin.AVX2_256/gmx
# Data prefix:  /home/thangavelucs/anaconda3/envs/md-intro-tutorial
# Working dir:  /home/thangavelucs/MD_Intro_Tutorial/md-intro-tutorial-main/kras_data
# Command line:
#   gmx pdb2gmx -f 1fjs_protein.pdb -o 1fjs_processed.gro -water tip3p -ff CHARMM36
#
# Using the CHARMM36 force field in directory ./CHARMM36.ff
#
# going to rename ./CHARMM36.ff/aminoacids.r2b
# Opening force field file ./CHARMM36.ff/aminoacids.r2b
#
# going to rename ./CHARMM36.ff/carb.r2b
# Opening force field file ./CHARMM36.ff/carb.r2b
#
# going to rename ./CHARMM36.ff/cgenff.r2b
# Opening force field file ./CHARMM36.ff/cgenff.r2b
#
# going to rename ./CHARMM36.ff/ethers.r2b
# Opening force field file ./CHARMM36.ff/ethers.r2b
#
# going to rename ./CHARMM36.ff/lipid.r2b
# Opening force field file ./CHARMM36.ff/lipid.r2b
#
# going to rename ./CHARMM36.ff/metals.r2b
# Opening force field file ./CHARMM36.ff/metals.r2b
#
# going to rename ./CHARMM36.ff/na.r2b
# Opening force field file ./CHARMM36.ff/na.r2b
#
# going to rename ./CHARMM36.ff/silicates.r2b
# Opening force field file ./CHARMM36.ff/silicates.r2b
#
# going to rename ./CHARMM36.ff/solvent.r2b
# Opening force field file ./CHARMM36.ff/solvent.r2b
# Reading 1fjs_protein.pdb...
# Read 'Protein in water t=   0.00000 step= 0', 535 atoms
#
# Analyzing pdb file
# Splitting chemical chains based on TER records or chain id changing.
#
# There are 1 chains and 0 blocks of water and 223 residues with 535 atoms
#
#   chain  #res #atoms
#
#   1 ' '   223    535
#
# All occupancies are one
# All occupancies are one
# Opening force field file ./CHARMM36.ff/atomtypes.atp
#
# Reading residue database... (CHARMM36)
# Opening force field file ./CHARMM36.ff/aminoacids.rtp
# Opening force field file ./CHARMM36.ff/carb.rtp
# Opening force field file ./CHARMM36.ff/cgenff.rtp
# Opening force field file ./CHARMM36.ff/ethers.rtp
# Opening force field file ./CHARMM36.ff/lipid.rtp
# Opening force field file ./CHARMM36.ff/metals.rtp
# Opening force field file ./CHARMM36.ff/na.rtp
# Opening force field file ./CHARMM36.ff/silicates.rtp
# Opening force field file ./CHARMM36.ff/solvent.rtp
# Opening force field file ./CHARMM36.ff/aminoacids.hdb
# Opening force field file ./CHARMM36.ff/carb.hdb
# Opening force field file ./CHARMM36.ff/cgenff.hdb
# Opening force field file ./CHARMM36.ff/ethers.hdb
# Opening force field file ./CHARMM36.ff/lipid.hdb
# Opening force field file ./CHARMM36.ff/metals.hdb
# Opening force field file ./CHARMM36.ff/na.hdb
# Opening force field file ./CHARMM36.ff/silicates.hdb
# Opening force field file ./CHARMM36.ff/solvent.hdb
# Opening force field file ./CHARMM36.ff/aminoacids.n.tdb
# Opening force field file ./CHARMM36.ff/carb.n.tdb
# Opening force field file ./CHARMM36.ff/cgenff.n.tdb
# Opening force field file ./CHARMM36.ff/ethers.n.tdb
# Opening force field file ./CHARMM36.ff/lipid.n.tdb
# Opening force field file ./CHARMM36.ff/metals.n.tdb
# Opening force field file ./CHARMM36.ff/na.n.tdb
# Opening force field file ./CHARMM36.ff/silicates.n.tdb
# Opening force field file ./CHARMM36.ff/solvent.n.tdb
# Opening force field file ./CHARMM36.ff/aminoacids.c.tdb
# Opening force field file ./CHARMM36.ff/carb.c.tdb
# Opening force field file ./CHARMM36.ff/cgenff.c.tdb
# Opening force field file ./CHARMM36.ff/ethers.c.tdb
# Opening force field file ./CHARMM36.ff/lipid.c.tdb
# Opening force field file ./CHARMM36.ff/metals.c.tdb
# Opening force field file ./CHARMM36.ff/na.c.tdb
# Opening force field file ./CHARMM36.ff/silicates.c.tdb
# Opening force field file ./CHARMM36.ff/solvent.c.tdb
#
# Back Off! I just backed up topol.top to ./#topol.top.6#
#
# Processing chain 1 (535 atoms, 223 residues)
#
# Identified residue LYS167 as a starting terminus.
#
# Residue NA3357 in chain has different type ('Ion') from residue LYS167 ('Protein'). This chain lacks identifiers, which makes it impossible to do strict classification of the start/end residues. Here we need to guess this residue should not be part of the chain and instead introduce a break, but that will be catastrophic if they should in fact be linked. Please check your structure, and add NA to residuetypes.dat if this was not correct.
#
# Residue NA3357 in chain has different type ('Ion') from residue LYS167 ('Protein'). This chain lacks identifiers, which makes it impossible to do strict classification of the start/end residues. Here we need to guess this residue should not be part of the chain and instead introduce a break, but that will be catastrophic if they should in fact be linked. Please check your structure, and add NA to residuetypes.dat if this was not correct.
#
# Residue NA3358 in chain has different type ('Ion') from residue LYS167 ('Protein'). This chain lacks identifiers, which makes it impossible to do strict classification of the start/end residues. Here we need to guess this residue should not be part of the chain and instead introduce a break, but that will be catastrophic if they should in fact be linked. Please check your structure, and add NA to residuetypes.dat if this was not correct.
#
# Residue NA3358 in chain has different type ('Ion') from residue LYS167 ('Protein'). This chain lacks identifiers, which makes it impossible to do strict classification of the start/end residues. Here we need to guess this residue should not be part of the chain and instead introduce a break, but that will be catastrophic if they should in fact be linked. Please check your structure, and add NA to residuetypes.dat if this was not correct.
#
# Residue NA3359 in chain has different type ('Ion') from residue LYS167 ('Protein'). This chain lacks identifiers, which makes it impossible to do strict classification of the start/end residues. Here we need to guess this residue should not be part of the chain and instead introduce a break, but that will be catastrophic if they should in fact be linked. Please check your structure, and add NA to residuetypes.dat if this was not correct.
#
# Residue NA3359 in chain has different type ('Ion') from residue LYS167 ('Protein'). This chain lacks identifiers, which makes it impossible to do strict classification of the start/end residues. Here we need to guess this residue should not be part of the chain and instead introduce a break, but that will be catastrophic if they should in fact be linked. Please check your structure, and add NA to residuetypes.dat if this was not correct.
#
# Residue NA3360 in chain has different type ('Ion') from residue LYS167 ('Protein'). This chain lacks identifiers, which makes it impossible to do strict classification of the start/end residues. Here we need to guess this residue should not be part of the chain and instead introduce a break, but that will be catastrophic if they should in fact be linked. Please check your structure, and add NA to residuetypes.dat if this was not correct.
#
# Residue NA3360 in chain has different type ('Ion') from residue LYS167 ('Protein'). This chain lacks identifiers, which makes it impossible to do strict classification of the start/end residues. Here we need to guess this residue should not be part of the chain and instead introduce a break, but that will be catastrophic if they should in fact be linked. Please check your structure, and add NA to residuetypes.dat if this was not correct.
#
# Residue NA3361 in chain has different type ('Ion') from residue LYS167 ('Protein'). This chain lacks identifiers, which makes it impossible to do strict classification of the start/end residues. Here we need to guess this residue should not be part of the chain and instead introduce a break, but that will be catastrophic if they should in fact be linked. Please check your structure, and add NA to residuetypes.dat if this was not correct.
#
# Residue NA3361 in chain has different type ('Ion') from residue LYS167 ('Protein'). This chain lacks identifiers, which makes it impossible to do strict classification of the start/end residues. Here we need to guess this residue should not be part of the chain and instead introduce a break, but that will be catastrophic if they should in fact be linked. Please check your structure, and add NA to residuetypes.dat if this was not correct.
#
# Disabling further warnings about unidentified residues at end of chain.
#
# Disabling further warnings about unidentified residues at end of chain.
#
# Identified residue LYS184 as a ending terminus.
# 8 out of 8 lines of specbond.dat converted successfully
# Start terminus LYS-167: NH3+
# End terminus LYS-184: COO-
# Opening force field file ./CHARMM36.ff/aminoacids.arn
#
# Checking for duplicate atoms....
#
# Generating any missing hydrogen atoms and/or adding termini.
#
# Now there are 223 residues with 537 atoms
#
# Making bonds...
#
# Number of bonds was 331, now 331
#
# Generating angles, dihedrals and pairs...
# Before cleaning: 890 pairs
# Before cleaning: 890 dihedrals
#
# Making cmap torsions...
#
# There are   16 cmap torsion pairs
#
# There are  890 dihedrals,   37 impropers,  619 angles
#            890 pairs,      331 bonds and     0 virtual sites
#
# Total mass 7692.470 a.m.u.
#
# Total charge 80.000 e
#
# Writing topology
#
# Writing coordinate file...
#
# 		--------- PLEASE NOTE ------------
#
# You have successfully generated a topology from: 1fjs_protein.pdb.
#
# The CHARMM36 force field and the tip3p water model are used.
#
# 		--------- ETON ESAELP ------------
#
# GROMACS reminds you: "Praise those of your critics for whom nothing is up to standard." (Dag Hammarskjold)

# %% [markdown]
# We chose the CHARMM36 all-atom force field. The force field will contain the information that will be written to the topology. read thoroughly about each force field and decide which is most applicable to your situation. Run `gmx pdb2gmx` without the -ff flag for more force field options

# %% [markdown]
#     Select the Force Field:
#     From '/usr/local/gromacs/share/gromacs/top':
#      1: AMBER03 protein, nucleic AMBER94 (Duan et al., J. Comp. Chem. 24, 1999-2012, 2003)
#      2: AMBER94 force field (Cornell et al., JACS 117, 5179-5197, 1995)
#      3: AMBER96 protein, nucleic AMBER94 (Kollman et al., Acc. Chem. Res. 29, 461-469, 1996)
#      4: AMBER99 protein, nucleic AMBER94 (Wang et al., J. Comp. Chem. 21, 1049-1074, 2000)
#      5: AMBER99SB protein, nucleic AMBER94 (Hornak et al., Proteins 65, 712-725, 2006)
#      6: AMBER99SB-ILDN protein, nucleic AMBER94 (Lindorff-Larsen et al., Proteins 78, 1950-58, 2010)
#      7: AMBERGS force field (Garcia & Sanbonmatsu, PNAS 99, 2782-2787, 2002)
#      8: CHARMM27 all-atom force field (CHARM22 plus CMAP for proteins)
#      9: GROMOS96 43a1 force field
#     10: GROMOS96 43a2 force field (improved alkane dihedrals)
#     11: GROMOS96 45a3 force field (Schuler JCC 2001 22 1205)
#     12: GROMOS96 53a5 force field (JCC 2004 vol 25 pag 1656)
#     13: GROMOS96 53a6 force field (JCC 2004 vol 25 pag 1656)
#     14: GROMOS96 54a7 force field (Eur. Biophys. J. (2011), 40,, 843-856, DOI: 10.1007/s00249-011-0700-9)
#     15: OPLS-AA/L all-atom force field (2001 aminoacid dihedrals)

# %% [markdown]
# Other options that can be passed to `gmx pdb2gmx` (see http://manual.gromacs.org/documentation/current/onlinehelp/gmx-pdb2gmx.html).
# Commonly used options are listed here:
#
# | Option | Effect |
# |--------|--------
# |-water  | Water model to use: none, spc, spce, tip3p, tip4p, tip5p, tips3p.|
# |-ignh   | Ignore H atoms in the PDB file; especially useful for NMR structures. Otherwise, if H atoms are present, they must be in the named exactly how the force fields in GROMACS expect them to be. Different conventions exist, so dealing with H atoms can occasionally be a headache! If you need to preserve the initial H coordinates, but renaming is required, then the Linux sed command is your friend.|
# |-ter    | Interactively assign charge states for N- and C-termini.|
# |-inter  | Interactively assign charge states for Glu, Asp, Lys, Arg, and His; choose which Cys are involved in disulfide bonds.|

# %% [markdown]
# ## A peek at the generated files

# %%
# !ls
# Out:
#  1fjs_processed.gro	  charmm36-jul2022.ff.tgz   topol.top
#  1fjs_protein_noCYF.pdb  'hvr060-040_pub (1).tar'  '#topol.top.1#'
#  1fjs_protein.pdb	  hvr060-040_pub.gro	   '#topol.top.2#'
#  1fjs_protein_tmp2.pdb	  hvr060-040_pub.pdb	   '#topol.top.3#'
#  1fjs_protein_tmp3.pdb	  hvr060-040_pub.xtc	   '#topol.top.4#'
#  1fjs_protein_tmp.pdb	  posre.itp		   '#topol.top.5#'
#  CHARMM36.ff		  SampleFile.txt	   '#topol.top.6#'

# %% [markdown]
# You have now generated three new files:
# -1fjs_processed.gro
# -topol.top
# -topol_Protein_chain_X.itp
# -posre_Protein_chain_X.itp
#
# 1fjs_processed.gro is a GROMACS-formatted structure file that contains all the atoms defined within the force field (i.e., H atoms have been added to the amino acids in the protein).
#
# The topol.top file is the system topology. gmx pdb2gmx` produces a force field-compliant topology
#
# The posre files contain information used to restrain the positions of heavy atoms
#
# A .gro file is not mandatory to use GROMACS, to write coordinate files. to use PDB format, specify output file with .pdb extension. see http://manual.gromacs.org/documentation/current/reference-manual/file-formats.html for different formats

# %% [markdown]
# # Understanding molecule "topologies"

# %% [markdown]
# Let's look at what is in the output topology (topol.top). Again, using a plain text editor, inspect its contents. After several comment lines (preceded by `;`), you will find the following:

# %%
pwd
# Out:
# '/home/thangavelucs/MD_Intro_Tutorial/md-intro-tutorial-main/kras_data'

# %%
# !cat kras_topol.top
# Out:
# ;
# ;	File 'topol.top' was generated
# ;	By user: unknown (200385879)
# ;	On host: fsitgl-hpc012p.ncifcrf.gov
# ;	At date: Fri May 31 21:55:56 2024
# ;
# ;	This is a standalone topology file
# ;
# ;	Created by:
# ;	              :-) GROMACS - gmx pdb2gmx, 2023.3-conda_forge (-:
# ;
# ;	Executable:   /home/thangavelucs/anaconda3/envs/md-intro-tutorial/bin.AVX2_256/gmx
# ;	Data prefix:  /home/thangavelucs/anaconda3/envs/md-intro-tutorial
# ;	Working dir:  /home/thangavelucs/MD_Intro_Tutorial/md-intro-tutorial-main/kras_data
# ;	Command line:
# ;	  gmx pdb2gmx -f 1fjs_protein.pdb -o 1fjs_processed.gro -water tip3p -ff CHARMM36
# ;	Force field was read from current directory or a relative path - path added.
# ;
#
# ; Include forcefield parameters
# #include "./CHARMM36.ff/forcefield.itp"
#
# [ moleculetype ]
# ; Name            nrexcl
# Protein             3
#
# [ atoms ]
# ;   nr       type  resnr residue  atom   cgnr     charge       mass  typeB    chargeB      massB
# ; residue 167 LYS rtp LYS  q +2.0
#      1        NH3    167    LYS      N      1       -0.3     14.007
#      2         HC    167    LYS     H1      2       0.33      1.008
#      3         HC    167    LYS     H2      3       0.33      1.008
#      4         HC    167    LYS     H3      4       0.33      1.008
#      5        CT1    167    LYS     CA      5       0.21     12.011
#      6        HB1    167    LYS     HA      5        0.1      1.008
#      7        CT2    167    LYS     CB      6      -0.18     12.011
#      8        HA2    167    LYS    HB1      6       0.09      1.008
#      9        HA2    167    LYS    HB2      6       0.09      1.008
#     10        CT2    167    LYS     CG      7      -0.18     12.011
#     11        HA2    167    LYS    HG1      7       0.09      1.008
#     12        HA2    167    LYS    HG2      7       0.09      1.008
#     13        CT2    167    LYS     CD      8      -0.18     12.011
#     14        HA2    167    LYS    HD1      8       0.09      1.008
#     15        HA2    167    LYS    HD2      8       0.09      1.008
#     16        CT2    167    LYS     CE      9       0.21     12.011
#     17        HA2    167    LYS    HE1      9       0.05      1.008
#     18        HA2    167    LYS    HE2      9       0.05      1.008
#     19        NH3    167    LYS     NZ      9       -0.3     14.007
#     20         HC    167    LYS    HZ1      9       0.33      1.008
#     21         HC    167    LYS    HZ2      9       0.33      1.008
#     22         HC    167    LYS    HZ3      9       0.33      1.008
#     23          C    167    LYS      C     10       0.51     12.011
#     24          O    167    LYS      O     10      -0.51    15.9994   ; qtot 2
# ; residue 168 GLU rtp GLU  q -1.0
#     25        NH1    168    GLU      N     11      -0.47     14.007
#     26          H    168    GLU     HN     11       0.31      1.008
#     27        CT1    168    GLU     CA     11       0.07     12.011
#     28        HB1    168    GLU     HA     11       0.09      1.008
#     29       CT2A    168    GLU     CB     12      -0.18     12.011
#     30        HA2    168    GLU    HB1     12       0.09      1.008
#     31        HA2    168    GLU    HB2     12       0.09      1.008
#     32        CT2    168    GLU     CG     13      -0.28     12.011
#     33        HA2    168    GLU    HG1     13       0.09      1.008
#     34        HA2    168    GLU    HG2     13       0.09      1.008
#     35         CC    168    GLU     CD     13       0.62     12.011
#     36         OC    168    GLU    OE1     13      -0.76    15.9994
#     37         OC    168    GLU    OE2     13      -0.76    15.9994
#     38          C    168    GLU      C     14       0.51     12.011
#     39          O    168    GLU      O     14      -0.51    15.9994   ; qtot 1
# ; residue 169 LYS rtp LYS  q +1.0
#     40        NH1    169    LYS      N     15      -0.47     14.007
#     41          H    169    LYS     HN     15       0.31      1.008
#     42        CT1    169    LYS     CA     15       0.07     12.011
#     43        HB1    169    LYS     HA     15       0.09      1.008
#     44        CT2    169    LYS     CB     16      -0.18     12.011
#     45        HA2    169    LYS    HB1     16       0.09      1.008
#     46        HA2    169    LYS    HB2     16       0.09      1.008
#     47        CT2    169    LYS     CG     17      -0.18     12.011
#     48        HA2    169    LYS    HG1     17       0.09      1.008
#     49        HA2    169    LYS    HG2     17       0.09      1.008
#     50        CT2    169    LYS     CD     18      -0.18     12.011
#     51        HA2    169    LYS    HD1     18       0.09      1.008
#     52        HA2    169    LYS    HD2     18       0.09      1.008
#     53        CT2    169    LYS     CE     19       0.21     12.011
#     54        HA2    169    LYS    HE1     19       0.05      1.008
#     55        HA2    169    LYS    HE2     19       0.05      1.008
#     56        NH3    169    LYS     NZ     19       -0.3     14.007
#     57         HC    169    LYS    HZ1     19       0.33      1.008
#     58         HC    169    LYS    HZ2     19       0.33      1.008
#     59         HC    169    LYS    HZ3     19       0.33      1.008
#     60          C    169    LYS      C     20       0.51     12.011
#     61          O    169    LYS      O     20      -0.51    15.9994   ; qtot 2
# ; residue 170 MET rtp MET  q  0.0
#     62        NH1    170    MET      N     21      -0.47     14.007
#     63          H    170    MET     HN     21       0.31      1.008
#     64        CT1    170    MET     CA     21       0.07     12.011
#     65        HB1    170    MET     HA     21       0.09      1.008
#     66        CT2    170    MET     CB     22      -0.18     12.011
#     67        HA2    170    MET    HB1     22       0.09      1.008
#     68        HA2    170    MET    HB2     22       0.09      1.008
#     69        CT2    170    MET     CG     23      -0.14     12.011
#     70        HA2    170    MET    HG1     23       0.09      1.008
#     71        HA2    170    MET    HG2     23       0.09      1.008
#     72          S    170    MET     SD     23      -0.09      32.06
#     73        CT3    170    MET     CE     23      -0.22     12.011
#     74        HA3    170    MET    HE1     23       0.09      1.008
#     75        HA3    170    MET    HE2     23       0.09      1.008
#     76        HA3    170    MET    HE3     23       0.09      1.008
#     77          C    170    MET      C     24       0.51     12.011
#     78          O    170    MET      O     24      -0.51    15.9994   ; qtot 2
# ; residue 171 SER rtp SER  q  0.0
#     79        NH1    171    SER      N     25      -0.47     14.007
#     80          H    171    SER     HN     25       0.31      1.008
#     81        CT1    171    SER     CA     25       0.07     12.011
#     82        HB1    171    SER     HA     25       0.09      1.008
#     83        CT2    171    SER     CB     26       0.05     12.011
#     84        HA2    171    SER    HB1     26       0.09      1.008
#     85        HA2    171    SER    HB2     26       0.09      1.008
#     86        OH1    171    SER     OG     26      -0.66    15.9994
#     87          H    171    SER    HG1     26       0.43      1.008
#     88          C    171    SER      C     27       0.51     12.011
#     89          O    171    SER      O     27      -0.51    15.9994   ; qtot 2
# ; residue 172 LYS rtp LYS  q +1.0
#     90        NH1    172    LYS      N     28      -0.47     14.007
#     91          H    172    LYS     HN     28       0.31      1.008
#     92        CT1    172    LYS     CA     28       0.07     12.011
#     93        HB1    172    LYS     HA     28       0.09      1.008
#     94        CT2    172    LYS     CB     29      -0.18     12.011
#     95        HA2    172    LYS    HB1     29       0.09      1.008
#     96        HA2    172    LYS    HB2     29       0.09      1.008
#     97        CT2    172    LYS     CG     30      -0.18     12.011
#     98        HA2    172    LYS    HG1     30       0.09      1.008
#     99        HA2    172    LYS    HG2     30       0.09      1.008
#    100        CT2    172    LYS     CD     31      -0.18     12.011
#    101        HA2    172    LYS    HD1     31       0.09      1.008
#    102        HA2    172    LYS    HD2     31       0.09      1.008
#    103        CT2    172    LYS     CE     32       0.21     12.011
#    104        HA2    172    LYS    HE1     32       0.05      1.008
#    105        HA2    172    LYS    HE2     32       0.05      1.008
#    106        NH3    172    LYS     NZ     32       -0.3     14.007
#    107         HC    172    LYS    HZ1     32       0.33      1.008
#    108         HC    172    LYS    HZ2     32       0.33      1.008
#    109         HC    172    LYS    HZ3     32       0.33      1.008
#    110          C    172    LYS      C     33       0.51     12.011
#    111          O    172    LYS      O     33      -0.51    15.9994   ; qtot 3
# ; residue 173 ASP rtp ASP  q -1.0
#    112        NH1    173    ASP      N     34      -0.47     14.007
#    113          H    173    ASP     HN     34       0.31      1.008
#    114        CT1    173    ASP     CA     34       0.07     12.011
#    115        HB1    173    ASP     HA     34       0.09      1.008
#    116       CT2A    173    ASP     CB     35      -0.28     12.011
#    117        HA2    173    ASP    HB1     35       0.09      1.008
#    118        HA2    173    ASP    HB2     35       0.09      1.008
#    119         CC    173    ASP     CG     35       0.62     12.011
#    120         OC    173    ASP    OD1     35      -0.76    15.9994
#    121         OC    173    ASP    OD2     35      -0.76    15.9994
#    122          C    173    ASP      C     36       0.51     12.011
#    123          O    173    ASP      O     36      -0.51    15.9994   ; qtot 2
# ; residue 174 GLY rtp GLY  q  0.0
#    124        NH1    174    GLY      N     37      -0.47     14.007
#    125          H    174    GLY     HN     37       0.31      1.008
#    126        CT2    174    GLY     CA     37      -0.02     12.011
#    127        HB2    174    GLY    HA1     37       0.09      1.008
#    128        HB2    174    GLY    HA2     37       0.09      1.008
#    129          C    174    GLY      C     38       0.51     12.011
#    130          O    174    GLY      O     38      -0.51    15.9994   ; qtot 2
# ; residue 175 LYS rtp LYS  q +1.0
#    131        NH1    175    LYS      N     39      -0.47     14.007
#    132          H    175    LYS     HN     39       0.31      1.008
#    133        CT1    175    LYS     CA     39       0.07     12.011
#    134        HB1    175    LYS     HA     39       0.09      1.008
#    135        CT2    175    LYS     CB     40      -0.18     12.011
#    136        HA2    175    LYS    HB1     40       0.09      1.008
#    137        HA2    175    LYS    HB2     40       0.09      1.008
#    138        CT2    175    LYS     CG     41      -0.18     12.011
#    139        HA2    175    LYS    HG1     41       0.09      1.008
#    140        HA2    175    LYS    HG2     41       0.09      1.008
#    141        CT2    175    LYS     CD     42      -0.18     12.011
#    142        HA2    175    LYS    HD1     42       0.09      1.008
#    143        HA2    175    LYS    HD2     42       0.09      1.008
#    144        CT2    175    LYS     CE     43       0.21     12.011
#    145        HA2    175    LYS    HE1     43       0.05      1.008
#    146        HA2    175    LYS    HE2     43       0.05      1.008
#    147        NH3    175    LYS     NZ     43       -0.3     14.007
#    148         HC    175    LYS    HZ1     43       0.33      1.008
#    149         HC    175    LYS    HZ2     43       0.33      1.008
#    150         HC    175    LYS    HZ3     43       0.33      1.008
#    151          C    175    LYS      C     44       0.51     12.011
#    152          O    175    LYS      O     44      -0.51    15.9994   ; qtot 3
# ; residue 176 LYS rtp LYS  q +1.0
#    153        NH1    176    LYS      N     45      -0.47     14.007
#    154          H    176    LYS     HN     45       0.31      1.008
#    155        CT1    176    LYS     CA     45       0.07     12.011
#    156        HB1    176    LYS     HA     45       0.09      1.008
#    157        CT2    176    LYS     CB     46      -0.18     12.011
#    158        HA2    176    LYS    HB1     46       0.09      1.008
#    159        HA2    176    LYS    HB2     46       0.09      1.008
#    160        CT2    176    LYS     CG     47      -0.18     12.011
#    161        HA2    176    LYS    HG1     47       0.09      1.008
#    162        HA2    176    LYS    HG2     47       0.09      1.008
#    163        CT2    176    LYS     CD     48      -0.18     12.011
#    164        HA2    176    LYS    HD1     48       0.09      1.008
#    165        HA2    176    LYS    HD2     48       0.09      1.008
#    166        CT2    176    LYS     CE     49       0.21     12.011
#    167        HA2    176    LYS    HE1     49       0.05      1.008
#    168        HA2    176    LYS    HE2     49       0.05      1.008
#    169        NH3    176    LYS     NZ     49       -0.3     14.007
#    170         HC    176    LYS    HZ1     49       0.33      1.008
#    171         HC    176    LYS    HZ2     49       0.33      1.008
#    172         HC    176    LYS    HZ3     49       0.33      1.008
#    173          C    176    LYS      C     50       0.51     12.011
#    174          O    176    LYS      O     50      -0.51    15.9994   ; qtot 4
# ; residue 177 LYS rtp LYS  q +1.0
#    175        NH1    177    LYS      N     51      -0.47     14.007
#    176          H    177    LYS     HN     51       0.31      1.008
#    177        CT1    177    LYS     CA     51       0.07     12.011
#    178        HB1    177    LYS     HA     51       0.09      1.008
#    179        CT2    177    LYS     CB     52      -0.18     12.011
#    180        HA2    177    LYS    HB1     52       0.09      1.008
#    181        HA2    177    LYS    HB2     52       0.09      1.008
#    182        CT2    177    LYS     CG     53      -0.18     12.011
#    183        HA2    177    LYS    HG1     53       0.09      1.008
#    184        HA2    177    LYS    HG2     53       0.09      1.008
#    185        CT2    177    LYS     CD     54      -0.18     12.011
#    186        HA2    177    LYS    HD1     54       0.09      1.008
#    187        HA2    177    LYS    HD2     54       0.09      1.008
#    188        CT2    177    LYS     CE     55       0.21     12.011
#    189        HA2    177    LYS    HE1     55       0.05      1.008
#    190        HA2    177    LYS    HE2     55       0.05      1.008
#    191        NH3    177    LYS     NZ     55       -0.3     14.007
#    192         HC    177    LYS    HZ1     55       0.33      1.008
#    193         HC    177    LYS    HZ2     55       0.33      1.008
#    194         HC    177    LYS    HZ3     55       0.33      1.008
#    195          C    177    LYS      C     56       0.51     12.011
#    196          O    177    LYS      O     56      -0.51    15.9994   ; qtot 5
# ; residue 178 LYS rtp LYS  q +1.0
#    197        NH1    178    LYS      N     57      -0.47     14.007
#    198          H    178    LYS     HN     57       0.31      1.008
#    199        CT1    178    LYS     CA     57       0.07     12.011
#    200        HB1    178    LYS     HA     57       0.09      1.008
#    201        CT2    178    LYS     CB     58      -0.18     12.011
#    202        HA2    178    LYS    HB1     58       0.09      1.008
#    203        HA2    178    LYS    HB2     58       0.09      1.008
#    204        CT2    178    LYS     CG     59      -0.18     12.011
#    205        HA2    178    LYS    HG1     59       0.09      1.008
#    206        HA2    178    LYS    HG2     59       0.09      1.008
#    207        CT2    178    LYS     CD     60      -0.18     12.011
#    208        HA2    178    LYS    HD1     60       0.09      1.008
#    209        HA2    178    LYS    HD2     60       0.09      1.008
#    210        CT2    178    LYS     CE     61       0.21     12.011
#    211        HA2    178    LYS    HE1     61       0.05      1.008
#    212        HA2    178    LYS    HE2     61       0.05      1.008
#    213        NH3    178    LYS     NZ     61       -0.3     14.007
#    214         HC    178    LYS    HZ1     61       0.33      1.008
#    215         HC    178    LYS    HZ2     61       0.33      1.008
#    216         HC    178    LYS    HZ3     61       0.33      1.008
#    217          C    178    LYS      C     62       0.51     12.011
#    218          O    178    LYS      O     62      -0.51    15.9994   ; qtot 6
# ; residue 179 LYS rtp LYS  q +1.0
#    219        NH1    179    LYS      N     63      -0.47     14.007
#    220          H    179    LYS     HN     63       0.31      1.008
#    221        CT1    179    LYS     CA     63       0.07     12.011
#    222        HB1    179    LYS     HA     63       0.09      1.008
#    223        CT2    179    LYS     CB     64      -0.18     12.011
#    224        HA2    179    LYS    HB1     64       0.09      1.008
#    225        HA2    179    LYS    HB2     64       0.09      1.008
#    226        CT2    179    LYS     CG     65      -0.18     12.011
#    227        HA2    179    LYS    HG1     65       0.09      1.008
#    228        HA2    179    LYS    HG2     65       0.09      1.008
#    229        CT2    179    LYS     CD     66      -0.18     12.011
#    230        HA2    179    LYS    HD1     66       0.09      1.008
#    231        HA2    179    LYS    HD2     66       0.09      1.008
#    232        CT2    179    LYS     CE     67       0.21     12.011
#    233        HA2    179    LYS    HE1     67       0.05      1.008
#    234        HA2    179    LYS    HE2     67       0.05      1.008
#    235        NH3    179    LYS     NZ     67       -0.3     14.007
#    236         HC    179    LYS    HZ1     67       0.33      1.008
#    237         HC    179    LYS    HZ2     67       0.33      1.008
#    238         HC    179    LYS    HZ3     67       0.33      1.008
#    239          C    179    LYS      C     68       0.51     12.011
#    240          O    179    LYS      O     68      -0.51    15.9994   ; qtot 7
# ; residue 180 LYS rtp LYS  q +1.0
#    241        NH1    180    LYS      N     69      -0.47     14.007
#    242          H    180    LYS     HN     69       0.31      1.008
#    243        CT1    180    LYS     CA     69       0.07     12.011
#    244        HB1    180    LYS     HA     69       0.09      1.008
#    245        CT2    180    LYS     CB     70      -0.18     12.011
#    246        HA2    180    LYS    HB1     70       0.09      1.008
#    247        HA2    180    LYS    HB2     70       0.09      1.008
#    248        CT2    180    LYS     CG     71      -0.18     12.011
#    249        HA2    180    LYS    HG1     71       0.09      1.008
#    250        HA2    180    LYS    HG2     71       0.09      1.008
#    251        CT2    180    LYS     CD     72      -0.18     12.011
#    252        HA2    180    LYS    HD1     72       0.09      1.008
#    253        HA2    180    LYS    HD2     72       0.09      1.008
#    254        CT2    180    LYS     CE     73       0.21     12.011
#    255        HA2    180    LYS    HE1     73       0.05      1.008
#    256        HA2    180    LYS    HE2     73       0.05      1.008
#    257        NH3    180    LYS     NZ     73       -0.3     14.007
#    258         HC    180    LYS    HZ1     73       0.33      1.008
#    259         HC    180    LYS    HZ2     73       0.33      1.008
#    260         HC    180    LYS    HZ3     73       0.33      1.008
#    261          C    180    LYS      C     74       0.51     12.011
#    262          O    180    LYS      O     74      -0.51    15.9994   ; qtot 8
# ; residue 181 SER rtp SER  q  0.0
#    263        NH1    181    SER      N     75      -0.47     14.007
#    264          H    181    SER     HN     75       0.31      1.008
#    265        CT1    181    SER     CA     75       0.07     12.011
#    266        HB1    181    SER     HA     75       0.09      1.008
#    267        CT2    181    SER     CB     76       0.05     12.011
#    268        HA2    181    SER    HB1     76       0.09      1.008
#    269        HA2    181    SER    HB2     76       0.09      1.008
#    270        OH1    181    SER     OG     76      -0.66    15.9994
#    271          H    181    SER    HG1     76       0.43      1.008
#    272          C    181    SER      C     77       0.51     12.011
#    273          O    181    SER      O     77      -0.51    15.9994   ; qtot 8
# ; residue 182 LYS rtp LYS  q +1.0
#    274        NH1    182    LYS      N     78      -0.47     14.007
#    275          H    182    LYS     HN     78       0.31      1.008
#    276        CT1    182    LYS     CA     78       0.07     12.011
#    277        HB1    182    LYS     HA     78       0.09      1.008
#    278        CT2    182    LYS     CB     79      -0.18     12.011
#    279        HA2    182    LYS    HB1     79       0.09      1.008
#    280        HA2    182    LYS    HB2     79       0.09      1.008
#    281        CT2    182    LYS     CG     80      -0.18     12.011
#    282        HA2    182    LYS    HG1     80       0.09      1.008
#    283        HA2    182    LYS    HG2     80       0.09      1.008
#    284        CT2    182    LYS     CD     81      -0.18     12.011
#    285        HA2    182    LYS    HD1     81       0.09      1.008
#    286        HA2    182    LYS    HD2     81       0.09      1.008
#    287        CT2    182    LYS     CE     82       0.21     12.011
#    288        HA2    182    LYS    HE1     82       0.05      1.008
#    289        HA2    182    LYS    HE2     82       0.05      1.008
#    290        NH3    182    LYS     NZ     82       -0.3     14.007
#    291         HC    182    LYS    HZ1     82       0.33      1.008
#    292         HC    182    LYS    HZ2     82       0.33      1.008
#    293         HC    182    LYS    HZ3     82       0.33      1.008
#    294          C    182    LYS      C     83       0.51     12.011
#    295          O    182    LYS      O     83      -0.51    15.9994   ; qtot 9
# ; residue 183 THR rtp THR  q  0.0
#    296        NH1    183    THR      N     84      -0.47     14.007
#    297          H    183    THR     HN     84       0.31      1.008
#    298        CT1    183    THR     CA     84       0.07     12.011
#    299        HB1    183    THR     HA     84       0.09      1.008
#    300        CT1    183    THR     CB     85       0.14     12.011
#    301        HA1    183    THR     HB     85       0.09      1.008
#    302        OH1    183    THR    OG1     85      -0.66    15.9994
#    303          H    183    THR    HG1     85       0.43      1.008
#    304        CT3    183    THR    CG2     86      -0.27     12.011
#    305        HA3    183    THR   HG21     86       0.09      1.008
#    306        HA3    183    THR   HG22     86       0.09      1.008
#    307        HA3    183    THR   HG23     86       0.09      1.008
#    308          C    183    THR      C     87       0.51     12.011
#    309          O    183    THR      O     87      -0.51    15.9994   ; qtot 9
# ; residue 184 LYS rtp LYS  q  0.0
#    310        NH1    184    LYS      N     88      -0.47     14.007
#    311          H    184    LYS     HN     88       0.31      1.008
#    312        CT1    184    LYS     CA     88       0.07     12.011
#    313        HB1    184    LYS     HA     88       0.09      1.008
#    314        CT2    184    LYS     CB     89      -0.18     12.011
#    315        HA2    184    LYS    HB1     89       0.09      1.008
#    316        HA2    184    LYS    HB2     89       0.09      1.008
#    317        CT2    184    LYS     CG     90      -0.18     12.011
#    318        HA2    184    LYS    HG1     90       0.09      1.008
#    319        HA2    184    LYS    HG2     90       0.09      1.008
#    320        CT2    184    LYS     CD     91      -0.18     12.011
#    321        HA2    184    LYS    HD1     91       0.09      1.008
#    322        HA2    184    LYS    HD2     91       0.09      1.008
#    323        CT2    184    LYS     CE     92       0.21     12.011
#    324        HA2    184    LYS    HE1     92       0.05      1.008
#    325        HA2    184    LYS    HE2     92       0.05      1.008
#    326        NH3    184    LYS     NZ     92       -0.3     14.007
#    327         HC    184    LYS    HZ1     92       0.33      1.008
#    328         HC    184    LYS    HZ2     92       0.33      1.008
#    329         HC    184    LYS    HZ3     92       0.33      1.008
#    330         CC    184    LYS      C     93       0.34     12.011
#    331         OC    184    LYS    OT1     94      -0.67    15.9994
#    332         OC    184    LYS    OT2     95      -0.67    15.9994   ; qtot 9
# ; residue 3357 NA  rtp NA   q +1.0
#    333        SOD   3357     NA     NA     96          1    22.9898   ; qtot 10
# ; residue 3358 NA  rtp NA   q +1.0
#    334        SOD   3358     NA     NA     97          1    22.9898   ; qtot 11
# ; residue 3359 NA  rtp NA   q +1.0
#    335        SOD   3359     NA     NA     98          1    22.9898   ; qtot 12
# ; residue 3360 NA  rtp NA   q +1.0
#    336        SOD   3360     NA     NA     99          1    22.9898   ; qtot 13
# ; residue 3361 NA  rtp NA   q +1.0
#    337        SOD   3361     NA     NA    100          1    22.9898   ; qtot 14
# ; residue 3362 NA  rtp NA   q +1.0
#    338        SOD   3362     NA     NA    101          1    22.9898   ; qtot 15
# ; residue 3363 NA  rtp NA   q +1.0
#    339        SOD   3363     NA     NA    102          1    22.9898   ; qtot 16
# ; residue 3364 NA  rtp NA   q +1.0
#    340        SOD   3364     NA     NA    103          1    22.9898   ; qtot 17
# ; residue 3365 NA  rtp NA   q +1.0
#    341        SOD   3365     NA     NA    104          1    22.9898   ; qtot 18
# ; residue 3366 NA  rtp NA   q +1.0
#    342        SOD   3366     NA     NA    105          1    22.9898   ; qtot 19
# ; residue 3367 NA  rtp NA   q +1.0
#    343        SOD   3367     NA     NA    106          1    22.9898   ; qtot 20
# ; residue 3368 NA  rtp NA   q +1.0
#    344        SOD   3368     NA     NA    107          1    22.9898   ; qtot 21
# ; residue 3369 NA  rtp NA   q +1.0
#    345        SOD   3369     NA     NA    108          1    22.9898   ; qtot 22
# ; residue 3370 NA  rtp NA   q +1.0
#    346        SOD   3370     NA     NA    109          1    22.9898   ; qtot 23
# ; residue 3371 NA  rtp NA   q +1.0
#    347        SOD   3371     NA     NA    110          1    22.9898   ; qtot 24
# ; residue 3372 NA  rtp NA   q +1.0
#    348        SOD   3372     NA     NA    111          1    22.9898   ; qtot 25
# ; residue 3373 NA  rtp NA   q +1.0
#    349        SOD   3373     NA     NA    112          1    22.9898   ; qtot 26
# ; residue 3374 NA  rtp NA   q +1.0
#    350        SOD   3374     NA     NA    113          1    22.9898   ; qtot 27
# ; residue 3375 NA  rtp NA   q +1.0
#    351        SOD   3375     NA     NA    114          1    22.9898   ; qtot 28
# ; residue 3376 NA  rtp NA   q +1.0
#    352        SOD   3376     NA     NA    115          1    22.9898   ; qtot 29
# ; residue 3377 NA  rtp NA   q +1.0
#    353        SOD   3377     NA     NA    116          1    22.9898   ; qtot 30
# ; residue 3378 NA  rtp NA   q +1.0
#    354        SOD   3378     NA     NA    117          1    22.9898   ; qtot 31
# ; residue 3379 NA  rtp NA   q +1.0
#    355        SOD   3379     NA     NA    118          1    22.9898   ; qtot 32
# ; residue 3380 NA  rtp NA   q +1.0
#    356        SOD   3380     NA     NA    119          1    22.9898   ; qtot 33
# ; residue 3381 NA  rtp NA   q +1.0
#    357        SOD   3381     NA     NA    120          1    22.9898   ; qtot 34
# ; residue 3382 NA  rtp NA   q +1.0
#    358        SOD   3382     NA     NA    121          1    22.9898   ; qtot 35
# ; residue 3383 NA  rtp NA   q +1.0
#    359        SOD   3383     NA     NA    122          1    22.9898   ; qtot 36
# ; residue 3384 NA  rtp NA   q +1.0
#    360        SOD   3384     NA     NA    123          1    22.9898   ; qtot 37
# ; residue 3385 NA  rtp NA   q +1.0
#    361        SOD   3385     NA     NA    124          1    22.9898   ; qtot 38
# ; residue 3386 NA  rtp NA   q +1.0
#    362        SOD   3386     NA     NA    125          1    22.9898   ; qtot 39
# ; residue 3387 NA  rtp NA   q +1.0
#    363        SOD   3387     NA     NA    126          1    22.9898   ; qtot 40
# ; residue 3388 NA  rtp NA   q +1.0
#    364        SOD   3388     NA     NA    127          1    22.9898   ; qtot 41
# ; residue 3389 NA  rtp NA   q +1.0
#    365        SOD   3389     NA     NA    128          1    22.9898   ; qtot 42
# ; residue 3390 NA  rtp NA   q +1.0
#    366        SOD   3390     NA     NA    129          1    22.9898   ; qtot 43
# ; residue 3391 NA  rtp NA   q +1.0
#    367        SOD   3391     NA     NA    130          1    22.9898   ; qtot 44
# ; residue 3392 NA  rtp NA   q +1.0
#    368        SOD   3392     NA     NA    131          1    22.9898   ; qtot 45
# ; residue 3393 NA  rtp NA   q +1.0
#    369        SOD   3393     NA     NA    132          1    22.9898   ; qtot 46
# ; residue 3394 NA  rtp NA   q +1.0
#    370        SOD   3394     NA     NA    133          1    22.9898   ; qtot 47
# ; residue 3395 NA  rtp NA   q +1.0
#    371        SOD   3395     NA     NA    134          1    22.9898   ; qtot 48
# ; residue 3396 NA  rtp NA   q +1.0
#    372        SOD   3396     NA     NA    135          1    22.9898   ; qtot 49
# ; residue 3397 NA  rtp NA   q +1.0
#    373        SOD   3397     NA     NA    136          1    22.9898   ; qtot 50
# ; residue 3398 NA  rtp NA   q +1.0
#    374        SOD   3398     NA     NA    137          1    22.9898   ; qtot 51
# ; residue 3399 NA  rtp NA   q +1.0
#    375        SOD   3399     NA     NA    138          1    22.9898   ; qtot 52
# ; residue 3400 NA  rtp NA   q +1.0
#    376        SOD   3400     NA     NA    139          1    22.9898   ; qtot 53
# ; residue 3401 NA  rtp NA   q +1.0
#    377        SOD   3401     NA     NA    140          1    22.9898   ; qtot 54
# ; residue 3402 NA  rtp NA   q +1.0
#    378        SOD   3402     NA     NA    141          1    22.9898   ; qtot 55
# ; residue 3403 NA  rtp NA   q +1.0
#    379        SOD   3403     NA     NA    142          1    22.9898   ; qtot 56
# ; residue 3404 NA  rtp NA   q +1.0
#    380        SOD   3404     NA     NA    143          1    22.9898   ; qtot 57
# ; residue 3405 NA  rtp NA   q +1.0
#    381        SOD   3405     NA     NA    144          1    22.9898   ; qtot 58
# ; residue 3406 NA  rtp NA   q +1.0
#    382        SOD   3406     NA     NA    145          1    22.9898   ; qtot 59
# ; residue 3407 NA  rtp NA   q +1.0
#    383        SOD   3407     NA     NA    146          1    22.9898   ; qtot 60
# ; residue 3408 NA  rtp NA   q +1.0
#    384        SOD   3408     NA     NA    147          1    22.9898   ; qtot 61
# ; residue 3409 NA  rtp NA   q +1.0
#    385        SOD   3409     NA     NA    148          1    22.9898   ; qtot 62
# ; residue 3410 NA  rtp NA   q +1.0
#    386        SOD   3410     NA     NA    149          1    22.9898   ; qtot 63
# ; residue 3411 NA  rtp NA   q +1.0
#    387        SOD   3411     NA     NA    150          1    22.9898   ; qtot 64
# ; residue 3412 NA  rtp NA   q +1.0
#    388        SOD   3412     NA     NA    151          1    22.9898   ; qtot 65
# ; residue 3413 NA  rtp NA   q +1.0
#    389        SOD   3413     NA     NA    152          1    22.9898   ; qtot 66
# ; residue 3414 NA  rtp NA   q +1.0
#    390        SOD   3414     NA     NA    153          1    22.9898   ; qtot 67
# ; residue 3415 NA  rtp NA   q +1.0
#    391        SOD   3415     NA     NA    154          1    22.9898   ; qtot 68
# ; residue 3416 NA  rtp NA   q +1.0
#    392        SOD   3416     NA     NA    155          1    22.9898   ; qtot 69
# ; residue 3417 NA  rtp NA   q +1.0
#    393        SOD   3417     NA     NA    156          1    22.9898   ; qtot 70
# ; residue 3418 NA  rtp NA   q +1.0
#    394        SOD   3418     NA     NA    157          1    22.9898   ; qtot 71
# ; residue 3419 NA  rtp NA   q +1.0
#    395        SOD   3419     NA     NA    158          1    22.9898   ; qtot 72
# ; residue 3420 NA  rtp NA   q +1.0
#    396        SOD   3420     NA     NA    159          1    22.9898   ; qtot 73
# ; residue 3421 NA  rtp NA   q +1.0
#    397        SOD   3421     NA     NA    160          1    22.9898   ; qtot 74
# ; residue 3422 NA  rtp NA   q +1.0
#    398        SOD   3422     NA     NA    161          1    22.9898   ; qtot 75
# ; residue 3423 NA  rtp NA   q +1.0
#    399        SOD   3423     NA     NA    162          1    22.9898   ; qtot 76
# ; residue 3424 NA  rtp NA   q +1.0
#    400        SOD   3424     NA     NA    163          1    22.9898   ; qtot 77
# ; residue 3425 NA  rtp NA   q +1.0
#    401        SOD   3425     NA     NA    164          1    22.9898   ; qtot 78
# ; residue 3426 NA  rtp NA   q +1.0
#    402        SOD   3426     NA     NA    165          1    22.9898   ; qtot 79
# ; residue 3427 NA  rtp NA   q +1.0
#    403        SOD   3427     NA     NA    166          1    22.9898   ; qtot 80
# ; residue 3428 NA  rtp NA   q +1.0
#    404        SOD   3428     NA     NA    167          1    22.9898   ; qtot 81
# ; residue 3429 NA  rtp NA   q +1.0
#    405        SOD   3429     NA     NA    168          1    22.9898   ; qtot 82
# ; residue 3430 NA  rtp NA   q +1.0
#    406        SOD   3430     NA     NA    169          1    22.9898   ; qtot 83
# ; residue 3431 NA  rtp NA   q +1.0
#    407        SOD   3431     NA     NA    170          1    22.9898   ; qtot 84
# ; residue 3432 NA  rtp NA   q +1.0
#    408        SOD   3432     NA     NA    171          1    22.9898   ; qtot 85
# ; residue 3433 NA  rtp NA   q +1.0
#    409        SOD   3433     NA     NA    172          1    22.9898   ; qtot 86
# ; residue 3434 NA  rtp NA   q +1.0
#    410        SOD   3434     NA     NA    173          1    22.9898   ; qtot 87
# ; residue 3435 NA  rtp NA   q +1.0
#    411        SOD   3435     NA     NA    174          1    22.9898   ; qtot 88
# ; residue 3436 NA  rtp NA   q +1.0
#    412        SOD   3436     NA     NA    175          1    22.9898   ; qtot 89
# ; residue 3437 NA  rtp NA   q +1.0
#    413        SOD   3437     NA     NA    176          1    22.9898   ; qtot 90
# ; residue 3438 NA  rtp NA   q +1.0
#    414        SOD   3438     NA     NA    177          1    22.9898   ; qtot 91
# ; residue 3439 NA  rtp NA   q +1.0
#    415        SOD   3439     NA     NA    178          1    22.9898   ; qtot 92
# ; residue 3440 NA  rtp NA   q +1.0
#    416        SOD   3440     NA     NA    179          1    22.9898   ; qtot 93
# ; residue 3441 NA  rtp NA   q +1.0
#    417        SOD   3441     NA     NA    180          1    22.9898   ; qtot 94
# ; residue 3442 NA  rtp NA   q +1.0
#    418        SOD   3442     NA     NA    181          1    22.9898   ; qtot 95
# ; residue 3443 NA  rtp NA   q +1.0
#    419        SOD   3443     NA     NA    182          1    22.9898   ; qtot 96
# ; residue 3444 NA  rtp NA   q +1.0
#    420        SOD   3444     NA     NA    183          1    22.9898   ; qtot 97
# ; residue 3445 NA  rtp NA   q +1.0
#    421        SOD   3445     NA     NA    184          1    22.9898   ; qtot 98
# ; residue 3446 NA  rtp NA   q +1.0
#    422        SOD   3446     NA     NA    185          1    22.9898   ; qtot 99
# ; residue 3447 NA  rtp NA   q +1.0
#    423        SOD   3447     NA     NA    186          1    22.9898   ; qtot 100
# ; residue 3448 NA  rtp NA   q +1.0
#    424        SOD   3448     NA     NA    187          1    22.9898   ; qtot 101
# ; residue 3449 NA  rtp NA   q +1.0
#    425        SOD   3449     NA     NA    188          1    22.9898   ; qtot 102
# ; residue 3450 NA  rtp NA   q +1.0
#    426        SOD   3450     NA     NA    189          1    22.9898   ; qtot 103
# ; residue 3451 NA  rtp NA   q +1.0
#    427        SOD   3451     NA     NA    190          1    22.9898   ; qtot 104
# ; residue 3452 NA  rtp NA   q +1.0
#    428        SOD   3452     NA     NA    191          1    22.9898   ; qtot 105
# ; residue 3453 NA  rtp NA   q +1.0
#    429        SOD   3453     NA     NA    192          1    22.9898   ; qtot 106
# ; residue 3454 NA  rtp NA   q +1.0
#    430        SOD   3454     NA     NA    193          1    22.9898   ; qtot 107
# ; residue 3455 NA  rtp NA   q +1.0
#    431        SOD   3455     NA     NA    194          1    22.9898   ; qtot 108
# ; residue 3456 NA  rtp NA   q +1.0
#    432        SOD   3456     NA     NA    195          1    22.9898   ; qtot 109
# ; residue 3457 NA  rtp NA   q +1.0
#    433        SOD   3457     NA     NA    196          1    22.9898   ; qtot 110
# ; residue 3458 NA  rtp NA   q +1.0
#    434        SOD   3458     NA     NA    197          1    22.9898   ; qtot 111
# ; residue 3459 NA  rtp NA   q +1.0
#    435        SOD   3459     NA     NA    198          1    22.9898   ; qtot 112
# ; residue 3460 NA  rtp NA   q +1.0
#    436        SOD   3460     NA     NA    199          1    22.9898   ; qtot 113
# ; residue 3461 NA  rtp NA   q +1.0
#    437        SOD   3461     NA     NA    200          1    22.9898   ; qtot 114
# ; residue 3462 NA  rtp NA   q +1.0
#    438        SOD   3462     NA     NA    201          1    22.9898   ; qtot 115
# ; residue 3463 NA  rtp NA   q +1.0
#    439        SOD   3463     NA     NA    202          1    22.9898   ; qtot 116
# ; residue 3464 NA  rtp NA   q +1.0
#    440        SOD   3464     NA     NA    203          1    22.9898   ; qtot 117
# ; residue 3465 NA  rtp NA   q +1.0
#    441        SOD   3465     NA     NA    204          1    22.9898   ; qtot 118
# ; residue 3466 NA  rtp NA   q +1.0
#    442        SOD   3466     NA     NA    205          1    22.9898   ; qtot 119
# ; residue 3467 NA  rtp NA   q +1.0
#    443        SOD   3467     NA     NA    206          1    22.9898   ; qtot 120
# ; residue 3468 NA  rtp NA   q +1.0
#    444        SOD   3468     NA     NA    207          1    22.9898   ; qtot 121
# ; residue 3469 NA  rtp NA   q +1.0
#    445        SOD   3469     NA     NA    208          1    22.9898   ; qtot 122
# ; residue 3470 NA  rtp NA   q +1.0
#    446        SOD   3470     NA     NA    209          1    22.9898   ; qtot 123
# ; residue 3471 NA  rtp NA   q +1.0
#    447        SOD   3471     NA     NA    210          1    22.9898   ; qtot 124
# ; residue 3472 NA  rtp NA   q +1.0
#    448        SOD   3472     NA     NA    211          1    22.9898   ; qtot 125
# ; residue 3473 NA  rtp NA   q +1.0
#    449        SOD   3473     NA     NA    212          1    22.9898   ; qtot 126
# ; residue 3474 NA  rtp NA   q +1.0
#    450        SOD   3474     NA     NA    213          1    22.9898   ; qtot 127
# ; residue 3475 NA  rtp NA   q +1.0
#    451        SOD   3475     NA     NA    214          1    22.9898   ; qtot 128
# ; residue 3476 NA  rtp NA   q +1.0
#    452        SOD   3476     NA     NA    215          1    22.9898   ; qtot 129
# ; residue 3477 NA  rtp NA   q +1.0
#    453        SOD   3477     NA     NA    216          1    22.9898   ; qtot 130
# ; residue 3478 NA  rtp NA   q +1.0
#    454        SOD   3478     NA     NA    217          1    22.9898   ; qtot 131
# ; residue 3479 NA  rtp NA   q +1.0
#    455        SOD   3479     NA     NA    218          1    22.9898   ; qtot 132
# ; residue 3480 NA  rtp NA   q +1.0
#    456        SOD   3480     NA     NA    219          1    22.9898   ; qtot 133
# ; residue 3481 NA  rtp NA   q +1.0
#    457        SOD   3481     NA     NA    220          1    22.9898   ; qtot 134
# ; residue 3482 NA  rtp NA   q +1.0
#    458        SOD   3482     NA     NA    221          1    22.9898   ; qtot 135
# ; residue 3483 NA  rtp NA   q +1.0
#    459        SOD   3483     NA     NA    222          1    22.9898   ; qtot 136
# ; residue 3484 NA  rtp NA   q +1.0
#    460        SOD   3484     NA     NA    223          1    22.9898   ; qtot 137
# ; residue 3485 NA  rtp NA   q +1.0
#    461        SOD   3485     NA     NA    224          1    22.9898   ; qtot 138
# ; residue 3486 NA  rtp NA   q +1.0
#    462        SOD   3486     NA     NA    225          1    22.9898   ; qtot 139
# ; residue 3487 NA  rtp NA   q +1.0
#    463        SOD   3487     NA     NA    226          1    22.9898   ; qtot 140
# ; residue 3488 NA  rtp NA   q +1.0
#    464        SOD   3488     NA     NA    227          1    22.9898   ; qtot 141
# ; residue 3489 NA  rtp NA   q +1.0
#    465        SOD   3489     NA     NA    228          1    22.9898   ; qtot 142
# ; residue 3490 NA  rtp NA   q +1.0
#    466        SOD   3490     NA     NA    229          1    22.9898   ; qtot 143
# ; residue 3491 NA  rtp NA   q +1.0
#    467        SOD   3491     NA     NA    230          1    22.9898   ; qtot 144
# ; residue 3492 NA  rtp NA   q +1.0
#    468        SOD   3492     NA     NA    231          1    22.9898   ; qtot 145
# ; residue 3493 NA  rtp NA   q +1.0
#    469        SOD   3493     NA     NA    232          1    22.9898   ; qtot 146
# ; residue 3494 NA  rtp NA   q +1.0
#    470        SOD   3494     NA     NA    233          1    22.9898   ; qtot 147
# ; residue 3495 CL  rtp CL   q -1.0
#    471        CLA   3495     CL     CL    234         -1      35.45   ; qtot 146
# ; residue 3496 CL  rtp CL   q -1.0
#    472        CLA   3496     CL     CL    235         -1      35.45   ; qtot 145
# ; residue 3497 CL  rtp CL   q -1.0
#    473        CLA   3497     CL     CL    236         -1      35.45   ; qtot 144
# ; residue 3498 CL  rtp CL   q -1.0
#    474        CLA   3498     CL     CL    237         -1      35.45   ; qtot 143
# ; residue 3499 CL  rtp CL   q -1.0
#    475        CLA   3499     CL     CL    238         -1      35.45   ; qtot 142
# ; residue 3500 CL  rtp CL   q -1.0
#    476        CLA   3500     CL     CL    239         -1      35.45   ; qtot 141
# ; residue 3501 CL  rtp CL   q -1.0
#    477        CLA   3501     CL     CL    240         -1      35.45   ; qtot 140
# ; residue 3502 CL  rtp CL   q -1.0
#    478        CLA   3502     CL     CL    241         -1      35.45   ; qtot 139
# ; residue 3503 CL  rtp CL   q -1.0
#    479        CLA   3503     CL     CL    242         -1      35.45   ; qtot 138
# ; residue 3504 CL  rtp CL   q -1.0
#    480        CLA   3504     CL     CL    243         -1      35.45   ; qtot 137
# ; residue 3505 CL  rtp CL   q -1.0
#    481        CLA   3505     CL     CL    244         -1      35.45   ; qtot 136
# ; residue 3506 CL  rtp CL   q -1.0
#    482        CLA   3506     CL     CL    245         -1      35.45   ; qtot 135
# ; residue 3507 CL  rtp CL   q -1.0
#    483        CLA   3507     CL     CL    246         -1      35.45   ; qtot 134
# ; residue 3508 CL  rtp CL   q -1.0
#    484        CLA   3508     CL     CL    247         -1      35.45   ; qtot 133
# ; residue 3509 CL  rtp CL   q -1.0
#    485        CLA   3509     CL     CL    248         -1      35.45   ; qtot 132
# ; residue 3510 CL  rtp CL   q -1.0
#    486        CLA   3510     CL     CL    249         -1      35.45   ; qtot 131
# ; residue 3511 CL  rtp CL   q -1.0
#    487        CLA   3511     CL     CL    250         -1      35.45   ; qtot 130
# ; residue 3512 CL  rtp CL   q -1.0
#    488        CLA   3512     CL     CL    251         -1      35.45   ; qtot 129
# ; residue 3513 CL  rtp CL   q -1.0
#    489        CLA   3513     CL     CL    252         -1      35.45   ; qtot 128
# ; residue 3514 CL  rtp CL   q -1.0
#    490        CLA   3514     CL     CL    253         -1      35.45   ; qtot 127
# ; residue 3515 CL  rtp CL   q -1.0
#    491        CLA   3515     CL     CL    254         -1      35.45   ; qtot 126
# ; residue 3516 CL  rtp CL   q -1.0
#    492        CLA   3516     CL     CL    255         -1      35.45   ; qtot 125
# ; residue 3517 CL  rtp CL   q -1.0
#    493        CLA   3517     CL     CL    256         -1      35.45   ; qtot 124
# ; residue 3518 CL  rtp CL   q -1.0
#    494        CLA   3518     CL     CL    257         -1      35.45   ; qtot 123
# ; residue 3519 CL  rtp CL   q -1.0
#    495        CLA   3519     CL     CL    258         -1      35.45   ; qtot 122
# ; residue 3520 CL  rtp CL   q -1.0
#    496        CLA   3520     CL     CL    259         -1      35.45   ; qtot 121
# ; residue 3521 CL  rtp CL   q -1.0
#    497        CLA   3521     CL     CL    260         -1      35.45   ; qtot 120
# ; residue 3522 CL  rtp CL   q -1.0
#    498        CLA   3522     CL     CL    261         -1      35.45   ; qtot 119
# ; residue 3523 CL  rtp CL   q -1.0
#    499        CLA   3523     CL     CL    262         -1      35.45   ; qtot 118
# ; residue 3524 CL  rtp CL   q -1.0
#    500        CLA   3524     CL     CL    263         -1      35.45   ; qtot 117
# ; residue 3525 CL  rtp CL   q -1.0
#    501        CLA   3525     CL     CL    264         -1      35.45   ; qtot 116
# ; residue 3526 CL  rtp CL   q -1.0
#    502        CLA   3526     CL     CL    265         -1      35.45   ; qtot 115
# ; residue 3527 CL  rtp CL   q -1.0
#    503        CLA   3527     CL     CL    266         -1      35.45   ; qtot 114
# ; residue 3528 CL  rtp CL   q -1.0
#    504        CLA   3528     CL     CL    267         -1      35.45   ; qtot 113
# ; residue 3529 CL  rtp CL   q -1.0
#    505        CLA   3529     CL     CL    268         -1      35.45   ; qtot 112
# ; residue 3530 CL  rtp CL   q -1.0
#    506        CLA   3530     CL     CL    269         -1      35.45   ; qtot 111
# ; residue 3531 CL  rtp CL   q -1.0
#    507        CLA   3531     CL     CL    270         -1      35.45   ; qtot 110
# ; residue 3532 CL  rtp CL   q -1.0
#    508        CLA   3532     CL     CL    271         -1      35.45   ; qtot 109
# ; residue 3533 CL  rtp CL   q -1.0
#    509        CLA   3533     CL     CL    272         -1      35.45   ; qtot 108
# ; residue 3534 CL  rtp CL   q -1.0
#    510        CLA   3534     CL     CL    273         -1      35.45   ; qtot 107
# ; residue 3535 CL  rtp CL   q -1.0
#    511        CLA   3535     CL     CL    274         -1      35.45   ; qtot 106
# ; residue 3536 CL  rtp CL   q -1.0
#    512        CLA   3536     CL     CL    275         -1      35.45   ; qtot 105
# ; residue 3537 CL  rtp CL   q -1.0
#    513        CLA   3537     CL     CL    276         -1      35.45   ; qtot 104
# ; residue 3538 CL  rtp CL   q -1.0
#    514        CLA   3538     CL     CL    277         -1      35.45   ; qtot 103
# ; residue 3539 CL  rtp CL   q -1.0
#    515        CLA   3539     CL     CL    278         -1      35.45   ; qtot 102
# ; residue 3540 CL  rtp CL   q -1.0
#    516        CLA   3540     CL     CL    279         -1      35.45   ; qtot 101
# ; residue 3541 CL  rtp CL   q -1.0
#    517        CLA   3541     CL     CL    280         -1      35.45   ; qtot 100
# ; residue 3542 CL  rtp CL   q -1.0
#    518        CLA   3542     CL     CL    281         -1      35.45   ; qtot 99
# ; residue 3543 CL  rtp CL   q -1.0
#    519        CLA   3543     CL     CL    282         -1      35.45   ; qtot 98
# ; residue 3544 CL  rtp CL   q -1.0
#    520        CLA   3544     CL     CL    283         -1      35.45   ; qtot 97
# ; residue 3545 CL  rtp CL   q -1.0
#    521        CLA   3545     CL     CL    284         -1      35.45   ; qtot 96
# ; residue 3546 CL  rtp CL   q -1.0
#    522        CLA   3546     CL     CL    285         -1      35.45   ; qtot 95
# ; residue 3547 CL  rtp CL   q -1.0
#    523        CLA   3547     CL     CL    286         -1      35.45   ; qtot 94
# ; residue 3548 CL  rtp CL   q -1.0
#    524        CLA   3548     CL     CL    287         -1      35.45   ; qtot 93
# ; residue 3549 CL  rtp CL   q -1.0
#    525        CLA   3549     CL     CL    288         -1      35.45   ; qtot 92
# ; residue 3550 CL  rtp CL   q -1.0
#    526        CLA   3550     CL     CL    289         -1      35.45   ; qtot 91
# ; residue 3551 CL  rtp CL   q -1.0
#    527        CLA   3551     CL     CL    290         -1      35.45   ; qtot 90
# ; residue 3552 CL  rtp CL   q -1.0
#    528        CLA   3552     CL     CL    291         -1      35.45   ; qtot 89
# ; residue 3553 CL  rtp CL   q -1.0
#    529        CLA   3553     CL     CL    292         -1      35.45   ; qtot 88
# ; residue 3554 CL  rtp CL   q -1.0
#    530        CLA   3554     CL     CL    293         -1      35.45   ; qtot 87
# ; residue 3555 CL  rtp CL   q -1.0
#    531        CLA   3555     CL     CL    294         -1      35.45   ; qtot 86
# ; residue 3556 CL  rtp CL   q -1.0
#    532        CLA   3556     CL     CL    295         -1      35.45   ; qtot 85
# ; residue 3557 CL  rtp CL   q -1.0
#    533        CLA   3557     CL     CL    296         -1      35.45   ; qtot 84
# ; residue 3558 CL  rtp CL   q -1.0
#    534        CLA   3558     CL     CL    297         -1      35.45   ; qtot 83
# ; residue 3559 CL  rtp CL   q -1.0
#    535        CLA   3559     CL     CL    298         -1      35.45   ; qtot 82
# ; residue 3560 CL  rtp CL   q -1.0
#    536        CLA   3560     CL     CL    299         -1      35.45   ; qtot 81
# ; residue 3561 CL  rtp CL   q -1.0
#    537        CLA   3561     CL     CL    300         -1      35.45   ; qtot 80
#
# [ bonds ]
# ...
#   163   166   169   171     9
#   163   166   169   172     9
#   167   166   169   170     9
#   167   166   169   171     9
#   167   166   169   172     9
#   168   166   169   170     9
#   168   166   169   171     9
#   168   166   169   172     9
#   155   173   175   176     9
#   155   173   175   177     9
#   174   173   175   176     9
#   310   312   330   331     9
#   310   312   330   332     9
#   313   312   330   331     9
#   313   312   330   332     9
#   314   312   330   331     9
#   314   312   330   332     9
#   312   314   317   318     9
#   312   314   317   319     9
#   312   314   317   320     9
#   315   314   317   318     9
#   315   314   317   319     9
#   315   314   317   320     9
#   316   314   317   318     9
#   316   314   317   319     9
#   316   314   317   320     9
#   314   317   320   321     9
#   314   317   320   322     9
#   314   317   320   323     9
#   318   317   320   321     9
#   318   317   320   322     9
#   318   317   320   323     9
#   319   317   320   321     9
#   319   317   320   322     9
#   319   317   320   323     9
#   317   320   323   324     9
#   317   320   323   325     9
#   317   320   323   326     9
#   321   320   323   324     9
#   321   320   323   325     9
#   321   320   323   326     9
#   322   320   323   324     9
#   322   320   323   325     9
#   322   320   323   326     9
#   320   323   326   327     9
#   320   323   326   328     9
#   320   323   326   329     9
#   324   323   326   327     9
#   324   323   326   328     9
#   324   323   326   329     9
#   325   323   326   327     9
#   325   323   326   328     9
#   325   323   326   329     9
#
# [ dihedrals ]
# ;  ai    aj    ak    al funct            c0            c1            c2            c3
#    23     5    25    24     2
#    25    23    27    26     2
#    35    32    37    36     2
#    38    27    40    39     2
#    40    38    42    41     2
#    60    42    62    61     2
#    62    60    64    63     2
#    77    64    79    78     2
#    79    77    81    80     2
#    88    81    90    89     2
#    90    88    92    91     2
#   110    92   112   111     2
#   112   110   114   113     2
#   119   116   121   120     2
#   122   114   124   123     2
#   124   122   126   125     2
#   129   126   131   130     2
#   131   129   133   132     2
#   151   133   153   152     2
#   153   151   155   154     2
#   173   155   175   174     2
#   175   173   177   176     2
#   195   177   197   196     2
#   197   195   199   198     2
#   217   199   219   218     2
#   219   217   221   220     2
#   239   221   241   240     2
#   241   239   243   242     2
#   261   243   263   262     2
#   263   261   265   264     2
#   272   265   274   273     2
#   274   272   276   275     2
#   294   276   296   295     2
#   296   294   298   297     2
#   308   298   310   309     2
#   310   308   312   311     2
#   330   312   332   331     2
#
# [ cmap ]
# ;  ai    aj    ak    al    am funct
#    23    25    27    38    40     1
#    38    40    42    60    62     1
#    60    62    64    77    79     1
#    77    79    81    88    90     1
#    88    90    92   110   112     1
#   110   112   114   122   124     1
#   122   124   126   129   131     1
#   129   131   133   151   153     1
#   151   153   155   173   175     1
#   173   175   177   195   197     1
#   195   197   199   217   219     1
#   217   219   221   239   241     1
#   239   241   243   261   263     1
#   261   263   265   272   274     1
#   272   274   276   294   296     1
#   294   296   298   308   310     1
#
# ; Include Position restraint file
# #ifdef POSRES
# #include "posre.itp"
# #endif
#
# ; Include water topology
# #include "./CHARMM36.ff/tip3p.itp"
#
# #ifdef POSRES_WATER
# ; Position restraint for each water oxygen
# [ position_restraints ]
# ;  i funct       fcx        fcy        fcz
#    1    1       1000       1000       1000
# #endif
#
# ; Include topology for ions
# #include "./CHARMM36.ff/ions.itp"
#
# [ system ]
# ; Name
# Protein in water t=   0.00000 step= 0
#
# [ molecules ]
# ; Compound        #mols
# Protein             1

# %% [markdown]
# The first line calls the parameters within the chosen force field. It is at the beginning of the file, indicating that all subsequent parameters are derived from this force field.  Then next important line is [ moleculetype ], that you find in

# %%
# !grep "moleculetype" -A 3 topol_Protein_chain_A.itp
# Out:
# [ moleculetype ]
# ; Name            nrexcl
# Protein_chain_A     3

# %% [markdown]
# and

# %%
# !grep "moleculetype" -A 3 topol_Protein_chain_L.itp
# Out:
# [ moleculetype ]
# ; Name            nrexcl
# Protein_chain_L     3

# %% [markdown]
# The name "Protein_chain_A" defines the molecule name, based on the fact that the protein was labeled as chain A in the PDB file. There are 3 exclusions for bonded neighbors. More information on exclusions can be found in the <a href=http://manual.gromacs.org/current/reference-manual/topologies.html>GROMACS manual</a>.

# %% [markdown]
# ## Atoms in a topology

# %% [markdown]
# The next section defines the [ atoms ] in the protein. The information is presented as columns:

# %%
! grep "atoms" -A 4 topol_Protein_chain_A.itp
# Out:
# [ atoms ]
# ;   nr       type  resnr residue  atom   cgnr     charge       mass  typeB    chargeB      massB
# ; residue  16 ILE rtp ILE  q +1.0
#      1        NH3     16    ILE      N      1       -0.3     14.007
#      2         HC     16    ILE     H1      2       0.33      1.008

# %% [markdown]
# The interpretation of this information is as follows:
#
# |Field  |  description |
# |--|--
# |nr|Atom number
# |type| Atom type
# |resnr|Amino acid residue number
# |residue| The amino acid residue name- Note that this may be different from .rtp entry.
# |atom| Atom name
# |cgnr| Charge group number - Not used anymore
# |charge| Self-explanatory - The "qtot" descriptor is a running total of the charge on the molecule
# |mass| Also self-explanatory
# |typeB, chargeB, massB| Used for free energy perturbation (not discussed here)

# %% [markdown]
# ## Bonds and other interactions

# %% [markdown]
# Subsequent sections include [ bonds ], [ pairs ], [ angles ], and [ dihedrals ]. Some of these sections are self-explanatory (bonds, angles, and dihedrals). These interactions are found [here](http://manual.gromacs.org/current/reference-manual/functions.html) and special 1-4 interactions are included under [pairs](http://manual.gromacs.org/current/reference-manual/functions/interaction-methods.html#exclusions-and-1-4-interactions). For format associated to function types [see topology file table](http://manual.gromacs.org/documentation/2020-beta1/reference-manual/topologies/topology-file-formats.html) in GROMACS manual.

# %% [markdown]
# Below we look for these interactions in topology file. As example we start with chain A. Bonded interactions

# %%
# !grep "bonds" -A 2 topol_Protein_chain_A.itp
# Out:
# [ bonds ]
# ;  ai    aj funct            c0            c1            c2            c3
#     1     2     1

# %% [markdown]
# Pair interactions

# %%
# !grep "pairs" -A 2  topol_Protein_chain_A.itp
# Out:
# [ pairs ]
# ;  ai    aj funct            c0            c1            c2            c3
#     1     8     1

# %% [markdown]
# Angle interactions

# %%
# !grep "angles" -A 2 topol_Protein_chain_A.itp
# Out:
# [ angles ]
# ;  ai    aj    ak funct            c0            c1            c2            c3
#     2     1     3     5

# %% [markdown]
# Dihedral interactions

# %%
# !grep "dihedrals" -A 2 topol_Protein_chain_A.itp
# Out:
# [ dihedrals ]
# ;  ai    aj    ak    al funct            c0            c1            c2            c3            c4            c5
#     2     1     5     6     9
# --
# [ dihedrals ]
# ;  ai    aj    ak    al funct            c0            c1            c2            c3
#    20     5    22    21     2

# %% [markdown]
# ## Water and position restraints

# %% [markdown]
# The remainder of the file has other useful/necessary topologies, starting with position restraints. The "posre.itp" file was generated by `gmx pdb2gmx`; it defines a force constant used to keep atoms in place during equilibration .

# %%
# !grep "posre" topol*.itp
# Out:
# topol_Protein_chain_A.itp:#include "posre_Protein_chain_A.itp"
# topol_Protein_chain_L.itp:#include "posre_Protein_chain_L.itp"

# %%
# !cat posre_Protein_chain_A.itp
# Out:
# ; In this topology include file, you will find position restraint
# ; entries for all the heavy atoms in your original pdb file.
# ; This means that all the protons which were added by pdb2gmx are
# ; not restrained.
#
# [ position_restraints ]
# ; atom  type      fx      fy      fz
#      1     1  1000  1000  1000
#      5     1  1000  1000  1000
#      7     1  1000  1000  1000
#      9     1  1000  1000  1000
#     13     1  1000  1000  1000
#     16     1  1000  1000  1000
#     20     1  1000  1000  1000
#     21     1  1000  1000  1000
#     22     1  1000  1000  1000
#     24     1  1000  1000  1000
#     26     1  1000  1000  1000
#     28     1  1000  1000  1000
#     32     1  1000  1000  1000
#     36     1  1000  1000  1000
#     37     1  1000  1000  1000
#     38     1  1000  1000  1000
#     40     1  1000  1000  1000
#     43     1  1000  1000  1000
#     44     1  1000  1000  1000
#     45     1  1000  1000  1000
#     47     1  1000  1000  1000
#     50     1  1000  1000  1000
#     51     1  1000  1000  1000
#     52     1  1000  1000  1000
#     54     1  1000  1000  1000
#     56     1  1000  1000  1000
#     59     1  1000  1000  1000
#     62     1  1000  1000  1000
#     63     1  1000  1000  1000
#     64     1  1000  1000  1000
#     67     1  1000  1000  1000
#     68     1  1000  1000  1000
#     69     1  1000  1000  1000
#     71     1  1000  1000  1000
#     73     1  1000  1000  1000
#     76     1  1000  1000  1000
#     79     1  1000  1000  1000
#     80     1  1000  1000  1000
#     81     1  1000  1000  1000
#     82     1  1000  1000  1000
#     83     1  1000  1000  1000
#     84     1  1000  1000  1000
#     86     1  1000  1000  1000
#     88     1  1000  1000  1000
#     91     1  1000  1000  1000
#     93     1  1000  1000  1000
#     94     1  1000  1000  1000
#     95     1  1000  1000  1000
#     97     1  1000  1000  1000
#     99     1  1000  1000  1000
#    102     1  1000  1000  1000
#    105     1  1000  1000  1000
#    108     1  1000  1000  1000
#    111     1  1000  1000  1000
#    115     1  1000  1000  1000
#    116     1  1000  1000  1000
#    117     1  1000  1000  1000
#    119     1  1000  1000  1000
#    121     1  1000  1000  1000
#    124     1  1000  1000  1000
#    125     1  1000  1000  1000
#    126     1  1000  1000  1000
#    127     1  1000  1000  1000
#    128     1  1000  1000  1000
#    129     1  1000  1000  1000
#    131     1  1000  1000  1000
#    134     1  1000  1000  1000
#    135     1  1000  1000  1000
#    136     1  1000  1000  1000
#    138     1  1000  1000  1000
#    140     1  1000  1000  1000
#    143     1  1000  1000  1000
#    146     1  1000  1000  1000
#    147     1  1000  1000  1000
#    148     1  1000  1000  1000
#    149     1  1000  1000  1000
#    150     1  1000  1000  1000
#    151     1  1000  1000  1000
#    153     1  1000  1000  1000
#    155     1  1000  1000  1000
#    158     1  1000  1000  1000
#    160     1  1000  1000  1000
#   3657     1  1000  1000  1000
#   3658     1  1000  1000  1000
#   3659     1  1000  1000  1000
#   3661     1  1000  1000  1000
#   3663     1  1000  1000  1000
#   3665     1  1000  1000  1000
#   3667     1  1000  1000  1000
#   3671     1  1000  1000  1000
#   3672     1  1000  1000  1000
#   3673     1  1000  1000  1000

# %% [markdown]
# Here ends the "Protein_chain_A" moleculetype definition. Then the "Protein_chain_L" moleculetype definition starts. The remainder of the topology file is dedicated to defining other molecules and providing system-level descriptions. The next moleculetype (by default) is the solvent, in this case TIP3P water. Other typical choices for water include SPC, SPC/E, and TIP4P. We chose this by passing "-water tip3p" to `gmx pdb2gmx`. For an excellent summary of the many different water models, click [here](http://www1.lsbu.ac.uk/water/water_models.html) , but be aware that not all of these models are present within GROMACS.

# %% [markdown]
# ## Ions and other parameters

# %% [markdown]
# Ion parameters are included next:

# %%
# !grep "ions" kras_topol.top
# Out:
# ; Include topology for ions
# #include "./CHARMM36.ff/ions.itp"

# %% [markdown]
# ## System level definitions

# %% [markdown]
# Finally come system-level definitions. The [ system ] directive gives the name of the system that will be written to output files during the simulation. The [ molecules ] directive lists all of the molecules in the system.

# %%
# !tail -8 kras_topol.top
# Out:
# [ system ]
# ; Name
# Protein in water t=   0.00000 step= 0
#
# [ molecules ]
# ; Compound        #mols
# Protein             1

# %% [markdown]
# A few key notes about the `[ molecules ]` directive:
#
# - The order of the listed molecules must exactly match the order of the molecules in the coordinate (in this case, .gro) file.
# - The names listed must match the `[ moleculetype ]` name for each species, not residue names or anything else.
#
# If you fail to satisfy these concrete requirements at any time, you will get fatal errors from grompp (discussed later) about mismatched names, molecules not being found, or a number of others.

# %% [markdown]
# Now that we have examined the contents of a topology file, we can continue building our system.

# %% [markdown]
# # Solvating the simulation system

# %% [markdown]
# Now that you are familiar with the contents of the GROMACS topology, it is time to continue building our system. In this example, we are going to be simulating a simple aqueous system. It is possible to simulate proteins and other molecules in different solvents, provided that good parameters are available for all species involved.
#
# There are two steps to defining the box and filling it with solvent:
#
# - Define the box dimensions using the [`gmx editconf`](https://manual.gromacs.org/current/onlinehelp/gmx-editconf.html) tool.
# - Fill the box with water using the [`gmx solvate`](https://manual.gromacs.org/current/onlinehelp/gmx-solvate.html) tool.
#
# You are now presented with a choice as to how to treat the unit cell. For the purpose of this tutorial, we will use the rhombic dodecahedron, as its volume is ~71% of the cubic box of the same periodic distance, thus saving on the number of water molecules that need to be added to solvate the protein.

# %% [markdown]
# ## Defining the simulation box

# %% [markdown]
# Let's define the box using `gmx editconf`:

# %%
# !gmx editconf -f 1fjs_processed.gro -o 1fjs_newbox.gro -c -d 1.0 -bt dodecahedron
# Out:
#                :-) GROMACS - gmx editconf, 2023.3-conda_forge (-:
#
# Executable:   /home/thangavelucs/anaconda3/envs/md-intro-tutorial/bin.AVX2_256/gmx
# Data prefix:  /home/thangavelucs/anaconda3/envs/md-intro-tutorial
# Working dir:  /home/thangavelucs/MD_Intro_Tutorial/md-intro-tutorial-main/kras_data
# Command line:
#   gmx editconf -f 1fjs_processed.gro -o 1fjs_newbox.gro -c -d 1.0 -bt dodecahedron
#
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 537 atoms
# Volume: 630.478 nm^3, corresponds to roughly 283700 electrons
# No velocities found
#     system size :  7.878  7.856 10.045 (nm)
#     diameter    : 13.754               (nm)
#     center      :  4.507  3.525  3.701 (nm)
#     box vectors :  7.912  7.912 10.070 (nm)
#     box angles  :  90.00  90.00  90.00 (degrees)
#     box volume  : 630.48               (nm^3)
#     shift       :  7.308  8.291  1.868 (nm)
# new center      : 11.815 11.815  5.570 (nm)
# new box vectors : 15.754 15.754 15.754 (nm)
# new box angles  :  60.00  60.00  90.00 (degrees)
# new box volume  :2764.64               (nm^3)
#
# GROMACS reminds you: "The scientific method is an integral part of human intelligence, and when it has once been set at work it can only be dismissed by dismissing the intelligence itself" (George H. Mead)

# %% [markdown]
# The above command centers the protein in the box (-c), and places it at least 1.0 nm from the box edge (-d 1.0). The box type is defined as a rhombic dodecahedron (-bt dodecahedron). Have a look at this [section](http://manual.gromacs.org/current/reference-manual/algorithms/periodic-boundary-conditions.html#pbc) in the manual for more on periodic boundary conditions and dodecahedrons.

# %% [markdown]
# The distance to the edge of the box is an important parameter. A protein should never interact with its periodic image (minimum image convention), otherwise the forces calculated will be spurious. The minimum image convention implies that the distance between two periodic images of the protein should be larger than the cut-off radius used to truncate non-bonded interactions. Here we will use a cut-off radius of 1.2 nm (see below). Specifying a solute-box distance of 1.0 nm will mean that there are at least 2.0 nm between any two periodic images of a protein. We expect that at that distance all protein-protein interactions are negligible.

# %% [markdown]
# ## Filling the box with water

# %%
# !gmx solvate -cp 1fjs_newbox.gro -cs spc216.gro -o 1fjs_solv.gro -p kras_topol.top
# Out:
#                :-) GROMACS - gmx solvate, 2023.3-conda_forge (-:
#
# Executable:   /home/thangavelucs/anaconda3/envs/md-intro-tutorial/bin.AVX2_256/gmx
# Data prefix:  /home/thangavelucs/anaconda3/envs/md-intro-tutorial
# Working dir:  /home/thangavelucs/MD_Intro_Tutorial/md-intro-tutorial-main/kras_data
# Command line:
#   gmx solvate -cp 1fjs_newbox.gro -cs spc216.gro -o 1fjs_solv.gro -p kras_topol.top
#
# Reading solute configuration
# Reading solvent configuration
#
# Initialising inter-atomic distances...
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# NOTE: From version 5.0 gmx solvate uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
#
# Generating solvent configuration
# Will generate new solvent configuration of 9x9x6 boxes
# Solvent box contains 289062 atoms in 96354 residues
# Removed 18036 solvent atoms due to solvent-solvent overlap
# Removed 1041 solvent atoms due to solute-solvent overlap
# Sorting configuration
# Found 1 molecule type:
#     SOL (   3 atoms): 89995 residues
# Generated solvent containing 269985 atoms in 89995 residues
# Writing generated configuration to 1fjs_solv.gro
#
# Output configuration contains 270522 atoms in 90218 residues
# Volume                 :     2764.64 (nm^3)
# Density                :     976.926 (g/l)
# Number of solvent molecules:  89995
#
# Processing topology
# Adding line for 89995 solvent molecules with resname (SOL) to topology file (kras_topol.top)
#
# Back Off! I just backed up kras_topol.top to ./#kras_topol.top.1#
#
# GROMACS reminds you: "I like single-molecule experiments because I hate to simulate 10^23 molecules at the same time." (Helmut Grubmüller)

# %% [markdown]
# The configuration of the protein (-cp) is contained in the output of the previous `gmx editconf` step, and the configuration of the solvent (-cs) is part of the standard GROMACS installation. We are using spc216.gro, which is a generic equilibrated 3-point solvent model box. You can use spc216.gro as the solvent configuration for SPC, SPC/E, or TIP3P water, since they are all three-point water models. The output is called 1fjs_solv.gro, and we tell solvate the name of the topology file (topol.top) so it can be modified. Note the changes to the [ molecules ] directive of topol.top:

# %%
# !tail kras_topol.top
# Out:
# #include "./CHARMM36.ff/ions.itp"
#
# [ system ]
# ; Name
# Protein in water t=   0.00000 step= 0
#
# [ molecules ]
# ; Compound        #mols
# Protein             1
# SOL             89995

# %% [markdown]
# `gmx solvate` kept track of how many water molecules it has added, which it then writes to your topology to reflect the changes that have been made. Note that if you use any other (non-water) solvent,`gmx solvate` will not make these changes to your topology! Its compatibility with updating water molecules is hard-coded.

# %% [markdown]
# # Adding Ions

# %% [markdown]
# We now have a solvated system that contains a charged protein. The output of `pdb2gmx` told us that the protein has a net charge of -2e (based on its amino acid composition). If you missed this information in the `pdb2gmx` output, look at the last line of each [ atoms ] directive in topology file; it should read  "qtot 1." for chain A and  "qtot -3." for chain L. Since life does not exist at a net charge, we must add ions to our system. Further, we aim to approximate physiological conditions and use therefore a NaCl concentration of 0.15 M.

# %% [markdown]
# ## Preparing the input for "gmx genion"

# %% [markdown]
# The tool for adding ions within GROMACS is called [`gmx genion`](https://manual.gromacs.org/current/onlinehelp/gmx-genion.html). What `gmx genion` does is read through the topology and replace water molecules with the ions that the user specifies. The input is called a run input file, which has an extension of .tpr; this file is produced by the GROMACS grompp module (GROMACS pre-processor), which will also be used later when we run our first simulation. `grompp` processes the coordinate file and topology (which describes the molecules) to generate an atomic-level input (`.tpr`). The .tpr file contains all the parameters for all of the atoms in the system.

# %% [markdown]
# To produce a .tpr file with [`gmx grompp`](https://manual.gromacs.org/current/onlinehelp/gmx-grompp.html), we will need an additional input file, with the extension .mdp (molecular dynamics parameter file); `gmx grompp` will assemble the parameters specified in the .mdp file with the coordinates and topology information to generate a .tpr file.

# %% [markdown]
# An .mdp file is normally used to run energy minimization or an MD simulation, but in this case is simply used to generate an atomic description of the system. We can proceed with an completely empty .mdp file in this case, its only role is to create the .tpr file.

# %%
# !touch ions.mdp

# %% [markdown]
# Assemble your .tpr file with the following:

# %%
# !gmx grompp -f ions.mdp -c 1fjs_solv.gro -p kras_topol.top -o ions.tpr
# Out:
#                 :-) GROMACS - gmx grompp, 2023.3-conda_forge (-:
#
# Executable:   /home/thangavelucs/anaconda3/envs/md-intro-tutorial/bin.AVX2_256/gmx
# Data prefix:  /home/thangavelucs/anaconda3/envs/md-intro-tutorial
# Working dir:  /home/thangavelucs/MD_Intro_Tutorial/md-intro-tutorial-main/kras_data
# Command line:
#   gmx grompp -f ions.mdp -c 1fjs_solv.gro -p kras_topol.top -o ions.tpr
#
#
# NOTE 1 [file ions.mdp]:
#   For a correct single-point energy evaluation with nsteps = 0, use
#   continuation = yes to avoid constraining the input coordinates.
#
# Setting the LD random seed to -1350966119
#
# Generated 167799 of the 167910 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 1
#
# Generated 117432 of the 167910 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# NOTE 2 [file kras_topol.top, line 3616]:
#   System has non-zero total charge: 80.000000
#   Total charge should normally be an integer. See
#   http://www.gromacs.org/Documentation/Floating_Point_Arithmetic
#   for discussion on how close it should be to an integer.
#
#
#
#
# NOTE 3 [file kras_topol.top, line 3616]:
#   In moleculetype 'Protein' 205 atoms are not bound by a potential or
#   constraint to any other atom in the same moleculetype. Although
#   technically this might not cause issues in a simulation, this often means
#   that the user forgot to add a bond/potential/constraint or put multiple
#   molecules in the same moleculetype definition by mistake. Run with -v to
#   get information for each atom.
#
#
# NOTE 4 [file kras_topol.top, line 3616]:
#   The bond in molecule-type Protein between atoms 86 OG and 87 HG1 has an
#   estimated oscillational period of 9.1e-03 ps, which is less than 10 times
#   the time step of 1.0e-03 ps.
#   Maybe you forgot to change the constraints mdp option.
#
# Analysing residue names:
# There are:    18    Protein residues
# There are:   205        Ion residues
# There are: 89995      Water residues
# Analysing Protein...
# Number of degrees of freedom in T-Coupling group rest is 541578.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# NOTE 5 [file ions.mdp]:
#   NVE simulation with an initial temperature of zero: will use a Verlet
#   buffer of 10%. Check your energy drift!
#
#
# NOTE 6 [file ions.mdp]:
#   You are using a plain Coulomb cut-off, which might produce artifacts.
#   You might want to consider using PME electrostatics.
#
#
#
# This run will generate roughly 21 Mb of data
#
# There were 6 NOTEs
#
# GROMACS reminds you: "Nullis in verba [Nobody's word is final]." (Motto of the Royal Society)

# %% [markdown]
# Be aware that there are some `NOTE` in the output. In all other cases than generating an output `tpr` for `gmx genion` these are very important and may not be ignored, here however we only need the atomic-level description of our system in the binary file ions.tpr. We will pass this file to genion:

# %% [markdown]
# *Note: A lot of GROMACS tools promt for input at the command line. As this does not play well with the jupyter notebook setup, we feed the input to the command line with a print command and a newline \n substituting enter*

# %%
# !printf "SOL\n" | gmx genion -s ions.tpr -o 1fjs_solv_ions.gro -conc 0.15 -p \
kras_topol.top -pname NA -nname CL -neutral
# Out:
#                 :-) GROMACS - gmx genion, 2023.3-conda_forge (-:
#
# Executable:   /home/thangavelucs/anaconda3/envs/md-intro-tutorial/bin.AVX2_256/gmx
# Data prefix:  /home/thangavelucs/anaconda3/envs/md-intro-tutorial
# Working dir:  /home/thangavelucs/MD_Intro_Tutorial/md-intro-tutorial-main/kras_data
# Command line:
#   gmx genion -s ions.tpr -o 1fjs_solv_ions.gro -conc 0.15 -p kras_topol.top -pname NA -nname CL -neutral
#
# Reading file ions.tpr, VERSION 2023.3-conda_forge (single precision)
# Reading file ions.tpr, VERSION 2023.3-conda_forge (single precision)
# Will try to add 250 NA ions and 330 CL ions.
# Select a continuous group of solvent molecules
# Group     0 (         System) has 270522 elements
# Group     1 (        Protein) has   332 elements
# Group     2 (      Protein-H) has   148 elements
# Group     3 (        C-alpha) has    18 elements
# Group     4 (       Backbone) has    54 elements
# Group     5 (      MainChain) has    71 elements
# Group     6 (   MainChain+Cb) has    88 elements
# Group     7 (    MainChain+H) has    91 elements
# Group     8 (      SideChain) has   241 elements
# Group     9 (    SideChain-H) has    77 elements
# Group    10 (    Prot-Masses) has   332 elements
# Group    11 (    non-Protein) has 270190 elements
# Group    12 (            Ion) has   205 elements
# Group    13 (          Water) has 269985 elements
# Group    14 (            SOL) has 269985 elements
# Group    15 (      non-Water) has   537 elements
# Group    16 ( Water_and_ions) has 270190 elements
# Select a group: Selected 14: 'SOL'
# Number of (3-atomic) solvent molecules: 89995
#
# Processing topology
# Replacing 580 solute molecules in topology file (kras_topol.top)  by 250 NA and 330 CL ions.
#
# Back Off! I just backed up kras_topol.top to ./#kras_topol.top.2#
# Using random seed -68159809.
# Replacing solvent molecule 35577 (atom 107268) with NA
# Replacing solvent molecule 56762 (atom 170823) with NA
# Replacing solvent molecule 134 (atom 939) with NA
# Replacing solvent molecule 41433 (atom 124836) with NA
# Replacing solvent molecule 38854 (atom 117099) with NA
# Replacing solvent molecule 55544 (atom 167169) with NA
# Replacing solvent molecule 85117 (atom 255888) with NA
# Replacing solvent molecule 43699 (atom 131634) with NA
# Replacing solvent molecule 34975 (atom 105462) with NA
# Replacing solvent molecule 43924 (atom 132309) with NA
# Replacing solvent molecule 50367 (atom 151638) with NA
# Replacing solvent molecule 78522 (atom 236103) with NA
# Replacing solvent molecule 68509 (atom 206064) with NA
# Replacing solvent molecule 72443 (atom 217866) with NA
# Replacing solvent molecule 30255 (atom 91302) with NA
# Replacing solvent molecule 17410 (atom 52767) with NA
# Replacing solvent molecule 58539 (atom 176154) with NA
# Replacing solvent molecule 45970 (atom 138447) with NA
# Replacing solvent molecule 56104 (atom 168849) with NA
# Replacing solvent molecule 22015 (atom 66582) with NA
# Replacing solvent molecule 75000 (atom 225537) with NA
# Replacing solvent molecule 82232 (atom 247233) with NA
# Replacing solvent molecule 86137 (atom 258948) with NA
# Replacing solvent molecule 5311 (atom 16470) with NA
# Replacing solvent molecule 38074 (atom 114759) with NA
# Replacing solvent molecule 86794 (atom 260919) with NA
# Replacing solvent molecule 54658 (atom 164511) with NA
# Replacing solvent molecule 43311 (atom 130470) with NA
# Replacing solvent molecule 55271 (atom 166350) with NA
# Replacing solvent molecule 84319 (atom 253494) with NA
# Replacing solvent molecule 87672 (atom 263553) with NA
# Replacing solvent molecule 26069 (atom 78744) with NA
# Replacing solvent molecule 66160 (atom 199017) with NA
# Replacing solvent molecule 47802 (atom 143943) with NA
# Replacing solvent molecule 80957 (atom 243408) with NA
# Replacing solvent molecule 15527 (atom 47118) with NA
# Replacing solvent molecule 75452 (atom 226893) with NA
# Replacing solvent molecule 77834 (atom 234039) with NA
# Replacing solvent molecule 34087 (atom 102798) with NA
# Replacing solvent molecule 24477 (atom 73968) with NA
# Replacing solvent molecule 8073 (atom 24756) with NA
# Replacing solvent molecule 28133 (atom 84936) with NA
# Replacing solvent molecule 18631 (atom 56430) with NA
# Replacing solvent molecule 21578 (atom 65271) with NA
# Replacing solvent molecule 66907 (atom 201258) with NA
# Replacing solvent molecule 22607 (atom 68358) with NA
# Replacing solvent molecule 89183 (atom 268086) with NA
# Replacing solvent molecule 4026 (atom 12615) with NA
# Replacing solvent molecule 67840 (atom 204057) with NA
# Replacing solvent molecule 44487 (atom 133998) with NA
# Replacing solvent molecule 21084 (atom 63789) with NA
# Replacing solvent molecule 46600 (atom 140337) with NA
# Replacing solvent molecule 86375 (atom 259662) with NA
# Replacing solvent molecule 88375 (atom 265662) with NA
# Replacing solvent molecule 66928 (atom 201321) with NA
# Replacing solvent molecule 14163 (atom 43026) with NA
# Replacing solvent molecule 34559 (atom 104214) with NA
# Replacing solvent molecule 19708 (atom 59661) with NA
# Replacing solvent molecule 35484 (atom 106989) with NA
# Replacing solvent molecule 32858 (atom 99111) with NA
# Replacing solvent molecule 48051 (atom 144690) with NA
# Replacing solvent molecule 84756 (atom 254805) with NA
# Replacing solvent molecule 1232 (atom 4233) with NA
# Replacing solvent molecule 70451 (atom 211890) with NA
# Replacing solvent molecule 87583 (atom 263286) with NA
# Replacing solvent molecule 34929 (atom 105324) with NA
# Replacing solvent molecule 78424 (atom 235809) with NA
# Replacing solvent molecule 49753 (atom 149796) with NA
# Replacing solvent molecule 17492 (atom 53013) with NA
# Replacing solvent molecule 38203 (atom 115146) with NA
# Replacing solvent molecule 60083 (atom 180786) with NA
# Replacing solvent molecule 82501 (atom 248040) with NA
# Replacing solvent molecule 71722 (atom 215703) with NA
# Replacing solvent molecule 32989 (atom 99504) with NA
# Replacing solvent molecule 86276 (atom 259365) with NA
# Replacing solvent molecule 13800 (atom 41937) with NA
# Replacing solvent molecule 24122 (atom 72903) with NA
# Replacing solvent molecule 3080 (atom 9777) with NA
# Replacing solvent molecule 55334 (atom 166539) with NA
# Replacing solvent molecule 47644 (atom 143469) with NA
# Replacing solvent molecule 10354 (atom 31599) with NA
# Replacing solvent molecule 1961 (atom 6420) with NA
# Replacing solvent molecule 17555 (atom 53202) with NA
# Replacing solvent molecule 80062 (atom 240723) with NA
# Replacing solvent molecule 40917 (atom 123288) with NA
# Replacing solvent molecule 83112 (atom 249873) with NA
# Replacing solvent molecule 27039 (atom 81654) with NA
# Replacing solvent molecule 15651 (atom 47490) with NA
# Replacing solvent molecule 9137 (atom 27948) with NA
# Replacing solvent molecule 64169 (atom 193044) with NA
# Replacing solvent molecule 14616 (atom 44385) with NA
# Replacing solvent molecule 38776 (atom 116865) with NA
# Replacing solvent molecule 31939 (atom 96354) with NA
# Replacing solvent molecule 77710 (atom 233667) with NA
# Replacing solvent molecule 36372 (atom 109653) with NA
# Replacing solvent molecule 35972 (atom 108453) with NA
# Replacing solvent molecule 1555 (atom 5202) with NA
# Replacing solvent molecule 89404 (atom 268749) with NA
# Replacing solvent molecule 65289 (atom 196404) with NA
# Replacing solvent molecule 18698 (atom 56631) with NA
# Replacing solvent molecule 63272 (atom 190353) with NA
# Replacing solvent molecule 24937 (atom 75348) with NA
# Replacing solvent molecule 4858 (atom 15111) with NA
# Replacing solvent molecule 81995 (atom 246522) with NA
# Replacing solvent molecule 50757 (atom 152808) with NA
# Replacing solvent molecule 23930 (atom 72327) with NA
# Replacing solvent molecule 16492 (atom 50013) with NA
# Replacing solvent molecule 9390 (atom 28707) with NA
# Replacing solvent molecule 48648 (atom 146481) with NA
# Replacing solvent molecule 51533 (atom 155136) with NA
# Replacing solvent molecule 60084 (atom 180789) with NA
# Replacing solvent molecule 64055 (atom 192702) with NA
# Replacing solvent molecule 7389 (atom 22704) with NA
# Replacing solvent molecule 60248 (atom 181281) with NA
# Replacing solvent molecule 87631 (atom 263430) with NA
# Replacing solvent molecule 58438 (atom 175851) with NA
# Replacing solvent molecule 22916 (atom 69285) with NA
# Replacing solvent molecule 75160 (atom 226017) with NA
# Replacing solvent molecule 29862 (atom 90123) with NA
# Replacing solvent molecule 7182 (atom 22083) with NA
# Replacing solvent molecule 2533 (atom 8136) with NA
# Replacing solvent molecule 14132 (atom 42933) with NA
# Replacing solvent molecule 58962 (atom 177423) with NA
# Replacing solvent molecule 51431 (atom 154830) with NA
# Replacing solvent molecule 87515 (atom 263082) with NA
# Replacing solvent molecule 1045 (atom 3672) with NA
# Replacing solvent molecule 78852 (atom 237093) with NA
# Replacing solvent molecule 71195 (atom 214122) with NA
# Replacing solvent molecule 22989 (atom 69504) with NA
# Replacing solvent molecule 51659 (atom 155514) with NA
# Replacing solvent molecule 22284 (atom 67389) with NA
# Replacing solvent molecule 28824 (atom 87009) with NA
# Replacing solvent molecule 18827 (atom 57018) with NA
# Replacing solvent molecule 45911 (atom 138270) with NA
# Replacing solvent molecule 32815 (atom 98982) with NA
# Replacing solvent molecule 3665 (atom 11532) with NA
# Replacing solvent molecule 70499 (atom 212034) with NA
# Replacing solvent molecule 11727 (atom 35718) with NA
# Replacing solvent molecule 30594 (atom 92319) with NA
# Replacing solvent molecule 13172 (atom 40053) with NA
# Replacing solvent molecule 55663 (atom 167526) with NA
# Replacing solvent molecule 72699 (atom 218634) with NA
# Replacing solvent molecule 79735 (atom 239742) with NA
# Replacing solvent molecule 32259 (atom 97314) with NA
# Replacing solvent molecule 83164 (atom 250029) with NA
# Replacing solvent molecule 49399 (atom 148734) with NA
# Replacing solvent molecule 32440 (atom 97857) with NA
# Replacing solvent molecule 68918 (atom 207291) with NA
# Replacing solvent molecule 36290 (atom 109407) with NA
# Replacing solvent molecule 53675 (atom 161562) with NA
# Replacing solvent molecule 68878 (atom 207171) with NA
# Replacing solvent molecule 2155 (atom 7002) with NA
# Replacing solvent molecule 36394 (atom 109719) with NA
# Replacing solvent molecule 5357 (atom 16608) with NA
# Replacing solvent molecule 8738 (atom 26751) with NA
# Replacing solvent molecule 32649 (atom 98484) with NA
# Replacing solvent molecule 4619 (atom 14394) with NA
# Replacing solvent molecule 20614 (atom 62379) with NA
# Replacing solvent molecule 23895 (atom 72222) with NA
# Replacing solvent molecule 8325 (atom 25512) with NA
# Replacing solvent molecule 13270 (atom 40347) with NA
# Replacing solvent molecule 36757 (atom 110808) with NA
# Replacing solvent molecule 36927 (atom 111318) with NA
# Replacing solvent molecule 37407 (atom 112758) with NA
# Replacing solvent molecule 9423 (atom 28806) with NA
# Replacing solvent molecule 76584 (atom 230289) with NA
# Replacing solvent molecule 74454 (atom 223899) with NA
# Replacing solvent molecule 9988 (atom 30501) with NA
# Replacing solvent molecule 33290 (atom 100407) with NA
# Replacing solvent molecule 42434 (atom 127839) with NA
# Replacing solvent molecule 19272 (atom 58353) with NA
# Replacing solvent molecule 67163 (atom 202026) with NA
# Replacing solvent molecule 28973 (atom 87456) with NA
# Replacing solvent molecule 38015 (atom 114582) with NA
# Replacing solvent molecule 75173 (atom 226056) with NA
# Replacing solvent molecule 38882 (atom 117183) with NA
# Replacing solvent molecule 42273 (atom 127356) with NA
# Replacing solvent molecule 39404 (atom 118749) with NA
# Replacing solvent molecule 9731 (atom 29730) with NA
# Replacing solvent molecule 20664 (atom 62529) with NA
# Replacing solvent molecule 59791 (atom 179910) with NA
# Replacing solvent molecule 65900 (atom 198237) with NA
# Replacing solvent molecule 76909 (atom 231264) with NA
# Replacing solvent molecule 75663 (atom 227526) with NA
# Replacing solvent molecule 38193 (atom 115116) with NA
# Replacing solvent molecule 48768 (atom 146841) with NA
# Replacing solvent molecule 36558 (atom 110211) with NA
# Replacing solvent molecule 26946 (atom 81375) with NA
# Replacing solvent molecule 60551 (atom 182190) with NA
# Replacing solvent molecule 61579 (atom 185274) with NA
# Replacing solvent molecule 12893 (atom 39216) with NA
# Replacing solvent molecule 46246 (atom 139275) with NA
# Replacing solvent molecule 76990 (atom 231507) with NA
# Replacing solvent molecule 69861 (atom 210120) with NA
# Replacing solvent molecule 75464 (atom 226929) with NA
# Replacing solvent molecule 46854 (atom 141099) with NA
# Replacing solvent molecule 55692 (atom 167613) with NA
# Replacing solvent molecule 52920 (atom 159297) with NA
# Replacing solvent molecule 49437 (atom 148848) with NA
# Replacing solvent molecule 22266 (atom 67335) with NA
# Replacing solvent molecule 40565 (atom 122232) with NA
# Replacing solvent molecule 88321 (atom 265500) with NA
# Replacing solvent molecule 56977 (atom 171468) with NA
# Replacing solvent molecule 71767 (atom 215838) with NA
# Replacing solvent molecule 16632 (atom 50433) with NA
# Replacing solvent molecule 85125 (atom 255912) with NA
# Replacing solvent molecule 30786 (atom 92895) with NA
# Replacing solvent molecule 83458 (atom 250911) with NA
# Replacing solvent molecule 37283 (atom 112386) with NA
# Replacing solvent molecule 44801 (atom 134940) with NA
# Replacing solvent molecule 1746 (atom 5775) with NA
# Replacing solvent molecule 59549 (atom 179184) with NA
# Replacing solvent molecule 45876 (atom 138165) with NA
# Replacing solvent molecule 11506 (atom 35055) with NA
# Replacing solvent molecule 76571 (atom 230250) with NA
# Replacing solvent molecule 5042 (atom 15663) with NA
# Replacing solvent molecule 6388 (atom 19701) with NA
# Replacing solvent molecule 75633 (atom 227436) with NA
# Replacing solvent molecule 30622 (atom 92403) with NA
# Replacing solvent molecule 49885 (atom 150192) with NA
# Replacing solvent molecule 15387 (atom 46698) with NA
# Replacing solvent molecule 67401 (atom 202740) with NA
# Replacing solvent molecule 31771 (atom 95850) with NA
# Replacing solvent molecule 480 (atom 1977) with NA
# Replacing solvent molecule 75515 (atom 227082) with NA
# Replacing solvent molecule 86168 (atom 259041) with NA
# Replacing solvent molecule 87968 (atom 264441) with NA
# Replacing solvent molecule 25924 (atom 78309) with NA
# Replacing solvent molecule 4348 (atom 13581) with NA
# Replacing solvent molecule 44714 (atom 134679) with NA
# Replacing solvent molecule 27238 (atom 82251) with NA
# Replacing solvent molecule 51849 (atom 156084) with NA
# Replacing solvent molecule 28487 (atom 85998) with NA
# Replacing solvent molecule 72576 (atom 218265) with NA
# Replacing solvent molecule 29994 (atom 90519) with NA
# Replacing solvent molecule 32548 (atom 98181) with NA
# Replacing solvent molecule 9668 (atom 29541) with NA
# Replacing solvent molecule 574 (atom 2259) with NA
# Replacing solvent molecule 33537 (atom 101148) with NA
# Replacing solvent molecule 23788 (atom 71901) with NA
# Replacing solvent molecule 44025 (atom 132612) with NA
# Replacing solvent molecule 81055 (atom 243702) with NA
# Replacing solvent molecule 49110 (atom 147867) with NA
# Replacing solvent molecule 28082 (atom 84783) with NA
# Replacing solvent molecule 9785 (atom 29892) with NA
# Replacing solvent molecule 15194 (atom 46119) with NA
# Replacing solvent molecule 62062 (atom 186723) with NA
# Replacing solvent molecule 57639 (atom 173454) with NA
# Replacing solvent molecule 65227 (atom 196218) with NA
# Replacing solvent molecule 71812 (atom 215973) with NA
# Replacing solvent molecule 59245 (atom 178272) with CL
# Replacing solvent molecule 28060 (atom 84717) with CL
# Replacing solvent molecule 19119 (atom 57894) with CL
# Replacing solvent molecule 76276 (atom 229365) with CL
# Replacing solvent molecule 30724 (atom 92709) with CL
# Replacing solvent molecule 32908 (atom 99261) with CL
# Replacing solvent molecule 54509 (atom 164064) with CL
# Replacing solvent molecule 26905 (atom 81252) with CL
# Replacing solvent molecule 1199 (atom 4134) with CL
# Replacing solvent molecule 21466 (atom 64935) with CL
# Replacing solvent molecule 79295 (atom 238422) with CL
# Replacing solvent molecule 14198 (atom 43131) with CL
# Replacing solvent molecule 15246 (atom 46275) with CL
# Replacing solvent molecule 551 (atom 2190) with CL
# Replacing solvent molecule 19549 (atom 59184) with CL
# Replacing solvent molecule 66456 (atom 199905) with CL
# Replacing solvent molecule 58425 (atom 175812) with CL
# Replacing solvent molecule 58033 (atom 174636) with CL
# Replacing solvent molecule 79306 (atom 238455) with CL
# Replacing solvent molecule 62921 (atom 189300) with CL
# Replacing solvent molecule 11695 (atom 35622) with CL
# Replacing solvent molecule 13621 (atom 41400) with CL
# Replacing solvent molecule 33479 (atom 100974) with CL
# Replacing solvent molecule 3239 (atom 10254) with CL
# Replacing solvent molecule 54500 (atom 164037) with CL
# Replacing solvent molecule 21258 (atom 64311) with CL
# Replacing solvent molecule 30076 (atom 90765) with CL
# Replacing solvent molecule 20934 (atom 63339) with CL
# Replacing solvent molecule 56251 (atom 169290) with CL
# Replacing solvent molecule 66756 (atom 200805) with CL
# Replacing solvent molecule 11582 (atom 35283) with CL
# Replacing solvent molecule 4582 (atom 14283) with CL
# Replacing solvent molecule 77702 (atom 233643) with CL
#
#
# GROMACS reminds you: "Misslycka kan man med all kod" (Mats Nylen)

# %% [markdown]
# We chose group "SOL" for embedding ions. You do not want to replace parts of your protein with ions.

# %% [markdown]
# *Note: Make sure to run `gmx genion` only once. `gmx genion` edits the topology "in-place" and does not know if there are already Cl or Na ions in the system. If you run it over again, ions will be added until there is no water left to replace with ions.*

# %% [markdown]
# In the `gmx genion` command, we provide the structure/state file (-s) as input, generate a .gro file as output (-o), process the topology (-p) to reflect the removal of water molecules and addition of ions, define positive and negative ion names (-pname and -nname, respectively), and tell `gmx genion` to add ions necessary to neutralize the net charge on the protein by adding the correct number of negative ions (-neutral, which in this case will add 2 Na+ ions to offset the -2 charge on the protein). We further use genion to add a specified concentration of ions in addition to simply neutralizing the system by specifying the -neutral and -conc options in conjunction. Refer to the genion man page for information on how to use these options.
#
# The names of the ions specified with -pname and -nname GROMACS are standardized and not dependent on the force-field. The specified ion names are always the elemental symbol in all capital letters, which is the [ moleculetype ] name that is then written to the topology. Residue or atom names may or may not append the sign of the charge (+/-), depending on the force field. Do not use atom or residue names in the genion command, or you will encounter errors in subsequent steps.

# %% [markdown]
# Your [ molecules ] directive should now be similar to

# %% [markdown]
#     [ molecules ]
#     ; Compound      #mols
#     Protein_chain_A    1
#     Protein_chain_L    1
#     SOL           11703
#     NA              38
#     CL              36

# %% [markdown]
# Let's check the last lines of the topology file

# %%
# !tail -6 kras_topol.top
# Out:
# [ molecules ]
# ; Compound        #mols
# Protein             1
# SOL         89415
# NA               250
# CL               330

# %% [markdown]
# If you see multiple lines of NA and CL, you most likely ran genion multiple times. Start over with the `pdb2gmx`.

# %% [markdown]
# # Energy minimisation

# %% [markdown]
# The solvated, electroneutral system is now assembled. Before we can begin dynamics, we must ensure that the system has no steric clashes or inappropriate geometry. The structure is relaxed through a process called energy minimization (EM).

# %% [markdown]
# To perform energy minimization, we are once again going to use `gmx grompp` to assemble the structure, topology, and simulation parameters into a binary input file (.tpr), then we will use GROMACS MD engine, mdrun, to run the energy minimization.

# %% [markdown]
# Assemble the binary input using `gmx grompp` using the .mdp parameter file, as input. The simulation parameter file (.mdp) determines how the simulation shall be run. Find more information on all the options in the [manual](http://manual.gromacs.org/documentation/current/user-guide/mdp-options.html) or in the following [webinar](https://bioexcel.eu/webinar-a-walk-through-simulation-parameter-options-mdp-files-for-gromacs-2019-12-05/). There are a lot of parameters that can be set, here we ony set the elemental parametes and leave everything else as default. Let's have a look at the input file:

# %%
# !cat input/emin-charmm.mdp
# Out:
# title       = CHARMM steepest descent enrgy minimisation
#
# ; Parameters describing what to do, when to stop and what to save
# integrator  = steep  ; Algorithm (steep = steepest descent minimization)
# emtol       = 1000.0 ; Stop minimization when the maximum force < 1000.0 kJ/mol/nm
# emstep      = 0.01   ; Minimization step size
# nstenergy   = 500    ; save energies every 1.0 ps, so we can observe if we are successful
# nsteps      = -1     ; run as long as we need
# ; Settings that make sure we run with parameters in harmony with the selected force-field
# constraints             = h-bonds   ; bonds involving H are constrained
# rcoulomb                = 1.2       ; short-range electrostatic cutoff (in nm)
# rvdw                    = 1.2       ; short-range van der Waals cutoff (in nm)
# vdw-modifier            = Force-switch ;  specific CHARMM
# rvdw_switch             = 1.0       ;
# DispCorr                = no        ; account for cut-off vdW scheme -
# ;in case of CHARMM DispCorr = EnerPres only for monolayers
# coulombtype             = PME       ; Particle Mesh Ewald for long-range electrostatics
# fourierspacing          = 0.15     ; grid spacing for FFT

# %%
# !gmx grompp -f emin-charmm.mdp -c 1fjs_solv_ions.gro -p kras_topol.top -o em.tpr
# Out:
#                 :-) GROMACS - gmx grompp, 2023.3-conda_forge (-:
#
# Executable:   /home/thangavelucs/anaconda3/envs/md-intro-tutorial/bin.AVX2_256/gmx
# Data prefix:  /home/thangavelucs/anaconda3/envs/md-intro-tutorial
# Working dir:  /home/thangavelucs/MD_Intro_Tutorial/md-intro-tutorial-main/kras_data
# Command line:
#   gmx grompp -f emin-charmm.mdp -c 1fjs_solv_ions.gro -p kras_topol.top -o em.tpr
#
# Ignoring obsolete mdp entry 'title'
# Setting the LD random seed to -346079373
#
# Generated 167799 of the 167910 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 1
#
# Generated 117432 of the 167910 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# Excluding 3 bonded neighbours molecule type 'NA'
#
# turning H bonds into constraints...
#
# Excluding 3 bonded neighbours molecule type 'CL'
#
# turning H bonds into constraints...
#
# NOTE 1 [file kras_topol.top, line 3618]:
#   In moleculetype 'Protein' 205 atoms are not bound by a potential or
#   constraint to any other atom in the same moleculetype. Although
#   technically this might not cause issues in a simulation, this often means
#   that the user forgot to add a bond/potential/constraint or put multiple
#   molecules in the same moleculetype definition by mistake. Run with -v to
#   get information for each atom.
#
# Analysing residue names:
# There are:    18    Protein residues
# There are:   785        Ion residues
# There are: 89415      Water residues
# Analysing Protein...
# Number of degrees of freedom in T-Coupling group rest is 539654.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# The largest distance between excluded atoms is 0.417 nm between atom 66 and 73
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 108x108x108, spacing 0.146 0.146 0.146
#
# Estimate for the relative computational load of the PME mesh part: 0.16
#
# This run will generate roughly 21 Mb of data
#
# There was 1 NOTE
#
# GROMACS reminds you: "Just a Minute While I Reinvent Myself" (Red Hot Chili Peppers)

# %% [markdown]
# Make sure you have been updating your topol.top file when running genbox and genion, or else you will get lots of nasty error messages ("number of coordinates in coordinate file does not match topology," etc).

# %% [markdown]
# Once run, we will find the energy-minimized structure in a file called `em.gro`. Additionally to this we will find more information on the run in an ASCII-text log file of the EM process,  `em.log`, a file for storage of energy, `em.edr` and a binary full-precision trajectory `em.trr`.

# %% [markdown]
# We are now ready to run mdrun to carry out the energy minimisation:

# %% [markdown]
# # Completed here to get em.gro for kras

# %%
# !gmx mdrun -v -deffnm em
# Out:
#                 :-) GROMACS - gmx mdrun, 2023.3-conda_forge (-:
#
# Executable:   /home/thangavelucs/anaconda3/envs/md-intro-tutorial/bin.AVX2_256/gmx
# Data prefix:  /home/thangavelucs/anaconda3/envs/md-intro-tutorial
# Working dir:  /home/thangavelucs/MD_Intro_Tutorial/md-intro-tutorial-main/kras_data
# Command line:
#   gmx mdrun -v -deffnm em
#
# Compiled SIMD is AVX2_256, but CPU also supports AVX_512 (see log).
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file em.tpr, VERSION 2023.3-conda_forge (single precision)
#
# Using 1 MPI thread
#
# Non-default thread affinity set, disabling internal thread affinity
#
# Using 1 OpenMP thread
#
#
# Steepest Descents:
#    Tolerance (Fmax)   =  1.00000e+03
#    Number of steps    
(ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000006, max 0.000034 (between atoms 94 and 95)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#      92     93   42.0    0.1124   0.1080      0.1080
#     112    113   40.9    0.0997   0.0997      0.0997
#      90     91   57.1    0.0997   0.0997      0.0997
# Step=   27, Dmax= 2.0e-01 nm, Epot= -4.07018e+06 Fmax= 7.00711e+04, atom= 173
#
# Step 28, time 0.028 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.071601, max 0.971238 (between atoms 112 and 113)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#      90     91   43.5    0.0997   0.0997      0.0997
#      92     93   39.1    0.1080   0.1080      0.1080
#     112    113   90.0    0.0997   0.1965      0.0997
#     155    156   36.5    0.1080   0.1080      0.1080
# Wrote pdb files with previous and current coordinates
# Step=   28, Dmax= 2.4e-01 nm, Epot=          inf Fmax= 1.29159e+05, atom= 110
# Step 29, time 0.029 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000012, max 0.000111 (between atoms 94 and 95)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#     112    113   80.3    0.0997   0.0997      0.0997
# Step=   29, Dmax= 1.2e-01 nm, Epot= -4.07992e+06 Fmax= 1.04094e+05, atom= 151
# Step=   30, Dmax= 1.4e-01 nm, Epot= -4.08972e+06 Fmax= 7.38202e+04, atom= 151
#
# Step 31, time 0.031 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000009, max 0.000085 (between atoms 126 and 127)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#     133    134   32.6    0.1080   0.1080      0.1080
# Step=   32, Dmax= 8.6e-02 nm, Epot= -4.10190e+06 Fmax= 3.94598e+04, atom= 151
# Step=   33, Dmax= 1.0e-01 nm, Epot= -4.10665e+06 Fmax= 9.13670e+04, atom= 173
# Step=   34, Dmax= 1.2e-01 nm, Epot= -4.11412e+06 Fmax= 8.51065e+04, atom= 173
# Step=   35, Dmax= 1.5e-01 nm, Epot= -4.11438e+06 Fmax= 1.97119e+05, atom= 173
#
# Step 36, time 0.036 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000005, max 0.000013 (between atoms 257 and 259)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#     155    156   33.8    0.1080   0.1080      0.1080
#     175    176   33.7    0.0997   0.0997      0.0997
# Step=   36, Dmax= 1.8e-01 nm, Epot= -4.12482e+06 Fmax= 6.78019e+04, atom= 173
#
# Step 37, time 0.037 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.043332, max 0.565134 (between atoms 175 and 176)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#     155    156   90.0    0.1080   0.1255      0.1080
#     175    176   90.0    0.0997   0.1560      0.0997
# Wrote pdb files with previous and current coordinates
# Step=   37, Dmax= 2.1e-01 nm, Epot=          inf Fmax= 1.97119e+05, atom= 173
# Step 38, time 0.038 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000009, max 0.000082 (between atoms 157 and 159)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#     155    156   35.5    0.1080   0.1080      0.1080
#     175    176   51.5    0.0997   0.0997      0.0997
# Step=   38, Dmax= 1.1e-01 nm, Epot= -4.13636e+06 Fmax= 2.09817e+04, atom= 173
#
# Step 39, time 0.039 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000163, max 0.002176 (between atoms 157 and 159)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#     153    154   35.4    0.0997   0.0997      0.0997
#     155    156   34.0    0.1080   0.1080      0.1080
#     175    176   34.3    0.0997   0.0997      0.0997
# Step=   39, Dmax= 1.3e-01 nm, Epot= -4.14351e+06 Fmax= 1.34585e+05, atom= 151
#
# Step 40, time 0.04 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000064, max 0.000649 (between atoms 157 and 159)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#     175    176   30.4    0.0997   0.0997      0.0997
# Step=   40, Dmax= 1.5e-01 nm, Epot= -4.15561e+06 Fmax= 5.89425e+04, atom= 151
#
# Step 41, time 0.041 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0
# Step=  354, Dmax= 3.8e-02 nm, Epot= -4.53007e+06 Fmax= 2.58562e+04, atom= 173
# Step=  356, Dmax= 2.3e-02 nm, Epot= -4.53092e+06 Fmax= 3.09290e+03, atom= 173
# Step=  357, Dmax= 2.7e-02 nm, Epot= -4.53173e+06 Fmax= 3.16136e+04, atom= 173
# Step=  358, Dmax= 3.3e-02 nm, Epot= -4.53290e+06 Fmax= 1.03428e+04, atom= 173
# Step=  360, Dmax= 2.0e-02 nm, Epot= -4.53315e+06 Fmax= 1.47106e+04, atom= 173
# Step=  361, Dmax= 2.3e-02 nm, Epot= -4.53347e+06 Fmax= 1.54443e+04, atom= 173
# Step=  362, Dmax= 2.8e-02 nm, Epot= -4.53364e+06 Fmax= 2.07418e+04, atom= 173
# Step=  363, Dmax= 3.4e-02 nm, Epot= -4.53386e+06 Fmax= 2.26915e+04, atom= 173
# Step=  364, Dmax= 4.0e-02 nm, Epot= -4.53387e+06 Fmax= 2.94338e+04, atom= 173
# Step=  365, Dmax= 4.9e-02 nm, Epot= -4.53397e+06 Fmax= 3.31066e+04, atom= 173
# Step=  367, Dmax= 2.9e-02 nm, Epot= -4.53532e+06 Fmax= 4.69612e+03, atom= 173
# Step=  369, Dmax= 1.7e-02 nm, Epot= -4.53580e+06 Fmax= 1.78895e+04, atom= 173
# Step=  370, Dmax= 2.1e-02 nm, Epot= -4.53627e+06 Fmax= 9.20464e+03, atom= 173
# Step=  371, Dmax= 2.5e-02 nm, Epot= -4.53635e+06 Fmax= 2.33208e+04, atom= 173
# Step=  372, Dmax= 3.0e-02 nm, Epot= -4.53692e+06 Fmax= 1.56787e+04, atom= 173
# Step=  374, Dmax= 1.8e-02 nm, Epot= -4.53735e+06 Fmax= 7.60884e+03, atom= 173
# Step=  375, Dmax= 2.2e-02 nm, Epot= -4.53757e+06 Fmax= 2.03433e+04, atom= 173
# Step=  376, Dmax= 2.6e-02 nm, Epot= -4.53806e+06 Fmax= 1.32293e+04, atom= 173
# Step=  378, Dmax= 1.6e-02 nm, Epot= -4.53843e+06 Fmax= 6.98290e+03, atom= 173
# Step=  379, Dmax= 1.9e-02 nm, Epot= -4.53871e+06 Fmax= 1.72896e+04, atom= 173
# Step=  380, Dmax= 2.3e-02 nm, Epot= -4.53913e+06 Fmax= 1.18116e+04, atom= 173
# Step=  381, Dmax= 2.7e-02 nm, Epot= -4.53920e+06 Fmax= 2.31239e+04, atom= 173
# Step=  382, Dmax= 3.2e-02 nm, Epot= -4.53964e+06 Fmax= 1.87731e+04, atom= 173
# Step=  384, Dmax= 1.9e-02 nm, Epot= -4.54018e+06 Fmax= 6.23497e+03, atom= 173
# Step=  385, Dmax= 2.3e-02 nm, Epot= -4.54032e+06 Fmax= 2.37984e+04, atom= 173
# Step=  386, Dmax= 2.8e-02 nm, Epot= -4.54099e+06 Fmax= 1.22802e+04, atom= 173
# Step=  388, Dmax= 1.7e-02 nm, Epot= -4.54133e+06 Fmax= 9.43141e+03, atom= 173
# Step=  389, Dmax= 2.0e-02 nm, Epot= -4.54157e+06 Fmax= 1.66366e+04, atom= 173
# Step=  460, Dmax= 1.7e-02 nm, Epot= -4.56204e+06 Fmax= 1.19061e+04, atom= 173
# Step=  461, Dmax= 2.0e-02 nm, Epot= -4.56224e+06 Fmax= 1.39967e+04, atom= 173
# Step=  462, Dmax= 2.4e-02 nm, Epot= -4.56239e+06 Fmax= 1.70927e+04, atom= 173
# Step=  463, Dmax= 2.9e-02 nm, Epot= -4.56247e+06 Fmax= 2.02054e+04, atom= 173
# Step=  465, Dmax= 1.7e-02 nm, Epot= -4.56323e+06 Fmax= 2.07356e+03, atom= 173
# Step=  466, Dmax= 2.1e-02 nm, Epot= -4.56386e+06 Fmax= 2.46765e+04, atom= 173
# Step=  467, Dmax= 2.5e-02 nm, Epot= -4.56495e+06 Fmax= 7.56394e+03, atom= 173
# Step=  469, Dmax= 1.5e-02 nm, Epot= -4.56513e+06 Fmax= 1.17205e+04, atom= 173
# Step=  470, Dmax= 1.8e-02 nm, Epot= -4.56539e+06 Fmax= 1.14705e+04, atom= 173
# Step=  471, Dmax= 2.2e-02 nm, Epot= -4.56545e+06 Fmax= 1.63619e+04, atom= 173
# Step=  472, Dmax= 2.6e-02 nm, Epot= -4.56566e+06 Fmax= 1.70403e+04, atom= 173
# Step=  474, Dmax= 1.6e-02 nm, Epot= -4.56628e+06 Fmax= 3.08982e+03, atom= 173
# Step=  475, Dmax= 1.9e-02 nm, Epot= -4.56656e+06 Fmax= 2.10651e+04, atom= 173
# Step=  476, Dmax= 2.2e-02 nm, Epot= -4.56736e+06 Fmax= 7.92007e+03, atom= 173
# Step=  478, Dmax= 1.3e-02 nm, Epot= -4.56758e+06 Fmax= 9.40560e+03, atom= 173
# Step=  479, Dmax= 1.6e-02 nm, Epot= -4.56778e+06 Fmax= 1.13796e+04, atom= 173
# Step=  480, Dmax= 1.9e-02 nm, Epot= -4.56795e+06 Fmax= 1.35679e+04, atom= 173
# Step=  481, Dmax= 2.3e-02 nm, Epot= -4.56809e+06 Fmax= 1.63619e+04, atom= 173
# Step=  482, Dmax= 2.8e-02 nm, Epot= -4.56815e+06 Fmax= 1.95554e+04, atom= 173
# Step=  484, Dmax= 1.7e-02 nm, Epot= -4.56891e+06 Fmax= 2.09905e+03, atom= 173
# Step=  485, Dmax= 2.0e-02 nm, Epot= -4.56952e+06 Fmax= 2.38825e+04, atom= 173
# Step=  486, Dmax= 2.4e-02 nm, Epot= -4.57047e+06 Fmax= 7.31046e+03, atom= 173
# Step=  488, Dmax= 1.4e-02 nm, Epot= -4.57068e+06 Fmax= 1.13266e+04, atom= 173
# Step=  489, Dmax= 1.7e-02 nm, Epot= -4.57092e+06 Fmax= 1.10289e+04, atom= 173
# Step=  490, Dmax= 2.1e-02 nm, Epot= -4.57100e+06 Fmax= 1.57983e+04, atom= 173
# Step=  491, Dmax= 2.5e-02 nm, Epot= -4.57122e+06 Fmax= 1.63889e+04, atom= 173
# Step=  493, Dmax= 1.5e-02 nm, Epot= -4.57178e+06 Fmax= 2.84370e+03, atom= 173
# Step=  529, Dmax= 2.3e-02 nm, Epot= -4.58151e+06 Fmax= 1.54102e+04, atom= 173
# Step=  531, Dmax= 1.4e-02 nm, Epot= -4.58202e+06 Fmax= 2.42527e+03, atom= 173
# Step=  532, Dmax= 1.7e-02 nm, Epot= -4.58231e+06 Fmax= 1.90125e+04, atom= 173
# Step=  533, Dmax= 2.0e-02 nm, Epot= -4.58304e+06 Fmax= 6.72697e+03, atom= 173
# Step=  535, Dmax= 1.2e-02 nm, Epot= -4.58321e+06 Fmax= 8.73699e+03, atom= 173
# Step=  536, Dmax= 1.4e-02 nm, Epot= -4.58340e+06 Fmax= 9.82414e+03, atom= 173
# Step=  537, Dmax= 1.7e-02 nm, Epot= -4.58355e+06 Fmax= 1.24452e+04, atom= 173
# Step=  538, Dmax= 2.1e-02 nm, Epot= -4.58367e+06 Fmax= 1.42796e+04, atom= 173
# Step=  539, Dmax= 2.5e-02 nm, Epot= -4.58368e+06 Fmax= 1.77854e+04, atom= 173
# Step=  540, Dmax= 3.0e-02 nm, Epot= -4.58369e+06 Fmax= 2.06900e+04, atom= 173
# Step=  542, Dmax= 1.8e-02 nm, Epot= -4.58463e+06 Fmax= 2.51197e+03, atom= 173
# Step=  544, Dmax= 1.1e-02 nm, Epot= -4.58496e+06 Fmax= 1.13578e+04, atom= 173
# Step=  545, Dmax= 1.3e-02 nm, Epot= -4.58528e+06 Fmax= 5.30025e+03, atom= 173
# Step=  546, Dmax= 1.5e-02 nm, Epot= -4.58535e+06 Fmax= 1.46864e+04, atom= 173
# Step=  547, Dmax= 1.9e-02 nm, Epot= -4.58576e+06 Fmax= 9.29299e+03, atom= 173
# Step=  549, Dmax= 1.1e-02 nm, Epot= -4.58603e+06 Fmax= 5.04658e+03, atom= 173
# Step=  550, Dmax= 1.3e-02 nm, Epot= -4.58616e+06 Fmax= 1.21692e+04, atom= 173
# Step=  551, Dmax= 1.6e-02 nm, Epot= -4.58649e+06 Fmax= 8.49181e+03, atom= 173
# Step=  553, Dmax= 9.6e-03 nm, Epot= -4.58673e+06 Fmax= 3.93707e+03, atom= 173
# Step=  554, Dmax= 1.2e-02 nm, Epot= -4.58693e+06 Fmax= 1.09787e+04, atom= 173
# Step=  555, Dmax= 1.4e-02 nm, Epot= -4.58723e+06 Fmax= 6.91836e+03, atom= 173
# Step=  556, Dmax= 1.7e-02 nm, Epot= -4.58724e+06 Fmax= 1.45580e+04, atom= 173
# Step=  557, Dmax= 2.0e-02 nm, Epot= -4.58759e+06 Fmax= 1.12079e+04, atom= 173
# Step=  559, Dmax= 1.2e-02 nm, Epot= -4.58792e+06 Fmax= 4.19619e+03, atom= 173
# Step=  560, Dmax= 1.4e-02 nm, Epot= -4.58798e+06 Fmax= 1.43037e+04, atom= 173
# Step=  561, Dmax= 1.7e-02 nm, Epot= -4.58840e+06 Fmax= 7.89650e+03, atom= 173
# Step=  563, Dmax= 1.0e-02 nm, Epot= -4.58864e+06 Fmax= 5.45880e+03, atom= 173
# Step=  564, Dmax= 1.2e-02 nm, Epot= -4.58881e+06 Fmax= 1.05673e+04, atom= 173
# Step=  565, Dmax= 1.5e-02 nm, Epot= -4.58907e+06 Fmax= 8.66076e+03, atom= 173
# Step=  566, Dmax= 1.8e-02 nm, Epot= -4.58907e+06 Fmax= 1.44137e+04, atom= 173
# Step=  567, Dmax= 2.1e-02 nm, Epot= -4.58933e+06 Fmax= 1.32689e+04, atom= 173
# Step=  569, Dmax= 1.3e-02 nm, Epot= -4.58978e+06 Fmax= 3.27847e+03, atom= 173
# Step=  570, Dmax= 1.5e-02 nm, Epot= -4.58985e+06 Fmax= 1.66035e+04, atom= 173
# Step=  571, Dmax= 1.9e-02 nm, Epot= -4.59043e+06 Fmax= 7.27818e+03, atom= 272
# Step=  573, Dmax= 1.1e-02 nm, Epot= -4.59062e+06 Fmax= 7.10191e+03, atom= 272
# Step=  574, Dmax= 1.3e-02 nm, Epot= -4.59076e+06 Fmax= 1.01089e+04, atom= 272
# Step=  575, Dmax= 1.6e-02 nm, Epot= -4.59094e+06 Fmax= 1.06006e+04, atom= 272
# Step=  576, Dmax= 1.9e-02 nm, Epot= -4.59101e+06 Fmax= 1.41936e+04, atom= 272
# Step=  577, Dmax= 2.3e-02 nm, Epot= -4.59113e+06 Fmax= 1.56281e+04, atom= 272
# Step=  579, Dmax= 1.4e-02 nm, Epot= -4.59172e+06 Fmax= 2.26216e+03, atom= 272
# Step=  580, Dmax= 1.7e-02 nm, Epot= -4.59197e+06 Fmax= 1.92735e+04, atom= 272
# Step=  581, Dmax= 2.0e-02 nm, Epot= -4.59271e+06 Fmax= 6.47101e+03, atom= 272
# Step=  583, Dmax= 1.2e-02 nm, Epot= -4.59287e+06 Fmax= 9.00066e+03, atom= 272
# Step=  584, Dmax= 1.4e-02 nm, Epot= -4.59303e+06 Fmax= 9.50523e+03, atom= 272
# Step=  585, Dmax= 1.7e-02 nm, Epot= -4.59312e+06 Fmax= 1.27655e+04, atom= 272
# Step=  586, Dmax= 2.1e-02 nm, Epot= -4.59325e+06 Fmax= 1.38943e+04, atom= 272
# Step=  588, Dmax= 1.2e-02 nm, Epot= -4.59371e+06 Fmax= 2.10789e+03, atom= 272
# Step=  589, Dmax= 1.5e-02 nm, Epot= -4.59404e+06 Fmax= 1.70297e+04, atom= 272
# Step=  590, Dmax= 1.8e-02 nm, Epot= -4.59468e+06 Fmax= 6.03587e+03, atom= 272
# Step=  592, Dmax= 1.1e-02 nm, Epot= -4.59487e+06 Fmax= 7.76699e+03, atom= 272
# Step=  593, Dmax= 1.3e-02 nm, Epot= -4.59505e+06 Fmax= 8.85842e+03, atom= 272
# Step=  594, Dmax= 1.5e-02 nm, Epot= -4.59518e+06 Fmax= 1.10318e+04, atom= 272
# Step=  595, Dmax= 1.9e-02 nm, Epot= -4.59529e+06 Fmax= 1.29035e+04, atom= 272
# Step=  596, Dmax= 2.2e-02 nm, Epot= -4.59534e+06 Fmax= 1.57524e+04, atom= 272
# Step=  597, Dmax= 2.7e-02 nm, Epot= -4.59538e+06 Fmax= 1.87147e+04, atom= 272
# Step=  633, Dmax= 1.7e-02 nm, Epot= -4.60343e+06 Fmax= 1.31506e+04, atom= 272
# Step=  634, Dmax= 2.1e-02 nm, Epot= -4.60357e+06 Fmax= 1.34241e+04, atom= 272
# Step=  636, Dmax= 1.2e-02 nm, Epot= -4.60396e+06 Fmax= 2.52740e+03, atom= 272
# Step=  637, Dmax= 1.5e-02 nm, Epot= -4.60422e+06 Fmax= 1.65510e+04, atom= 272
# Step=  638, Dmax= 1.8e-02 nm, Epot= -4.60473e+06 Fmax= 6.43700e+03, atom= 272
# Step=  640, Dmax= 1.1e-02 nm, Epot= -4.60487e+06 Fmax= 7.32523e+03, atom= 272
# Step=  641, Dmax= 1.3e-02 nm, Epot= -4.60502e+06 Fmax= 9.24813e+03, atom= 272
# Step=  642, Dmax= 1.5e-02 nm, Epot= -4.60516e+06 Fmax= 1.05794e+04, atom= 272
# Step=  643, Dmax= 1.8e-02 nm, Epot= -4.60524e+06 Fmax= 1.32802e+04, atom= 272
# Step=  644, Dmax= 2.2e-02 nm, Epot= -4.60537e+06 Fmax= 1.52845e+04, atom= 272
# Step=  646, Dmax= 1.3e-02 nm, Epot= -4.60583e+06 Fmax= 1.85806e+03, atom= 272
# Step=  647, Dmax= 1.6e-02 nm, Epot= -4.60621e+06 Fmax= 1.86413e+04, atom= 272
# Step=  648, Dmax= 1.9e-02 nm, Epot= -4.60682e+06 Fmax= 6.07406e+03, atom= 272
# Step=  650, Dmax= 1.1e-02 nm, Epot= -4.60698e+06 Fmax= 8.70996e+03, atom= 272
# Step=  651, Dmax= 1.4e-02 nm, Epot= -4.60714e+06 Fmax= 9.10173e+03, atom= 272
# Step=  652, Dmax= 1.7e-02 nm, Epot= -4.60721e+06 Fmax= 1.22088e+04, atom= 272
# Step=  653, Dmax= 2.0e-02 nm, Epot= -4.60734e+06 Fmax= 1.34348e+04, atom= 272
# Step=  655, Dmax= 1.2e-02 nm, Epot= -4.60771e+06 Fmax= 1.94141e+03, atom= 272
# Step=  656, Dmax= 1.4e-02 nm, Epot= -4.60808e+06 Fmax= 1.66015e+04, atom= 272
# Step=  657, Dmax= 1.7e-02 nm, Epot= -4.60858e+06 Fmax= 5.53171e+03, atom= 272
# Step=  659, Dmax= 1.0e-02 nm, Epot= -4.60876e+06 Fmax= 7.77361e+03, atom= 272
# Step=  660, Dmax= 1.2e-02 nm, Epot= -4.60891e+06 Fmax= 8.13510e+03, atom= 272
# Step=  661, Dmax= 1.5e-02 nm, Epot= -4.60902e+06 Fmax= 1.10158e+04, atom= 272
# Step=  662, Dmax= 1.8e-02 nm, Epot= -4.60918e+06 Fmax= 1.19035e+04, atom= 272
# Step=  663, Dmax= 2.1e-02 nm, Epot= -4.60921e+06 Fmax= 1.56691e+04, atom= 272
# Step=  664, Dmax= 2.6e-02 nm, Epot= -4.60930e+06 Fmax= 1.73487e+04, atom= 272
# Step=  666, Dmax= 1.5e-02 nm, Epot= -4.60984e+06 Fmax= 2.45617e+03, atom= 272
# Step=  667, Dmax= 1.8e-02 nm, Epot= -4.61000e+06 Fmax= 2.12684e+04, atom= 272
# Step=  668, Dmax= 2.2e-02 nm, Epot= -4.61070e+06 Fmax= 7.28656e+03, atom= 272
# Step=  670, Dmax= 1.3e-02 nm, Epot= -4.61079e+06 Fmax= 9.80581e+03, atom= 272
# Step=  671, Dmax= 1.6e-02 nm, Epot= -4.61094e+06 Fmax= 1.07732e+04, atom= 272
# Step=  672, Dmax= 1.9e-02 nm, Epot= -4.61100e+06 Fmax= 1.38590e+04, atom= 272
# Step=  673, Dmax= 2.3e-02 nm, Epot= -4.61108e+06 Fmax= 1.57724e+04, atom= 272
# Step=  675, Dmax= 1.4e-02 nm, Epot= -4.61155e+06 Fmax= 2.00397e+03, atom= 272
# Step=  676, Dmax= 1.7e-02 nm, Epot= -4.61186e+06 Fmax= 1.94121e+04, atom= 272
# Step=  677, Dmax= 2.0e-02 nm, Epot= -4.61245e+06 Fmax= 6.17212e+03, atom= 272
# ...
# Step= 1496, Dmax= 1.3e-02 nm, Epot= -4.70066e+06 Fmax= 9.26988e+03, atom= 272
# Step= 1497, Dmax= 1.6e-02 nm, Epot= -4.70066e+06 Fmax= 1.16644e+04, atom= 272
# Step= 1498, Dmax= 1.9e-02 nm, Epot= -4.70069e+06 Fmax= 1.34240e+04, atom= 272
# Step= 1500, Dmax= 1.2e-02 nm, Epot= -4.70086e+06 Fmax= 1.61295e+03, atom= 272
# Step= 1501, Dmax= 1.4e-02 nm, Epot= -4.70099e+06 Fmax= 1.63883e+04, atom= 272
# Step= 1502, Dmax= 1.7e-02 nm, Epot= -4.70123e+06 Fmax= 5.28220e+03, atom= 272
# Step= 1504, Dmax= 1.0e-02 nm, Epot= -4.70127e+06 Fmax= 7.70844e+03, atom= 272
# Step= 1505, Dmax= 1.2e-02 nm, Epot= -4.70133e+06 Fmax= 7.91737e+03, atom= 272
# Step= 1506, Dmax= 1.5e-02 nm, Epot= -4.70136e+06 Fmax= 1.08002e+04, atom= 272
# Step= 1507, Dmax= 1.7e-02 nm, Epot= -4.70140e+06 Fmax= 1.16990e+04, atom= 272
# Step= 1509, Dmax= 1.0e-02 nm, Epot= -4.70154e+06 Fmax= 1.80955e+03, atom= 272
# Step= 1510, Dmax= 1.3e-02 nm, Epot= -4.70161e+06 Fmax= 1.44522e+04, atom= 272
# Step= 1511, Dmax= 1.5e-02 nm, Epot= -4.70180e+06 Fmax= 5.00092e+03, atom= 272
# Step= 1513, Dmax= 9.0e-03 nm, Epot= -4.70186e+06 Fmax= 6.66768e+03, atom= 272
# Step= 1514, Dmax= 1.1e-02 nm, Epot= -4.70190e+06 Fmax= 7.30757e+03, atom= 272
# Step= 1515, Dmax= 1.3e-02 nm, Epot= -4.70194e+06 Fmax= 9.49298e+03, atom= 272
# Step= 1516, Dmax= 1.6e-02 nm, Epot= -4.70199e+06 Fmax= 1.06365e+04, atom= 272
# Step= 1517, Dmax= 1.9e-02 nm, Epot= -4.70201e+06 Fmax= 1.35554e+04, atom= 272
# Step= 1518, Dmax= 2.2e-02 nm, Epot= -4.70202e+06 Fmax= 1.54396e+04, atom= 272
# Step= 1589, Dmax= 7.8e-03 nm, Epot= -4.70670e+06 Fmax= 8.08886e+03, atom= 272
# Step= 1590, Dmax= 9.3e-03 nm, Epot= -4.70677e+06 Fmax= 3.93354e+03, atom= 272
# Step= 1591, Dmax= 1.1e-02 nm, Epot= -4.70678e+06 Fmax= 1.05258e+04, atom= 272
# Step= 1592, Dmax= 1.3e-02 nm, Epot= -4.70689e+06 Fmax= 6.79130e+03, atom= 272
# Step= 1594, Dmax= 8.0e-03 nm, Epot= -4.70695e+06 Fmax= 3.59464e+03, atom= 272
# Step= 1595, Dmax= 9.7e-03 nm, Epot= -4.70701e+06 Fmax= 8.84685e+03, atom= 272
# Step= 1596, Dmax= 1.2e-02 nm, Epot= -4.70709e+06 Fmax= 6.11149e+03, atom= 272
# Step= 1597, Dmax= 1.4e-02 nm, Epot= -4.70710e+06 Fmax= 1.18114e+04, atom= 272
# Step= 1598, Dmax= 1.7e-02 nm, Epot= -4.70716e+06 Fmax= 9.72985e+03, atom= 272
# Step= 1600, Dmax= 1.0e-02 nm, Epot= -4.70727e+06 Fmax= 3.20255e+03, atom= 272
# Step= 1602, Dmax= 6.0e-03 nm, Epot= -4.70733e+06 Fmax= 4.55928e+03, atom= 272
# Step= 1603, Dmax= 7.2e-03 nm, Epot= -4.70736e+06 Fmax= 4.73578e+03, atom= 272
# Step= 1604, Dmax= 8.6e-03 nm, Epot= -4.70741e+06 Fmax= 6.44101e+03, atom= 272
# Step= 1605, Dmax= 1.0e-02 nm, Epot= -4.70746e+06 Fmax= 6.94734e+03, atom= 272
# Step= 1606, Dmax= 1.2e-02 nm, Epot= -4.70751e+06 Fmax= 9.14666e+03, atom= 272
# Step= 1607, Dmax= 1.5e-02 nm, Epot= -4.70755e+06 Fmax= 1.01378e+04, atom= 272
# Step= 1608, Dmax= 1.8e-02 nm, Epot= -4.70756e+06 Fmax= 1.30372e+04, atom= 272
# Step= 1609, Dmax= 2.2e-02 nm, Epot= -4.70758e+06 Fmax= 1.47404e+04, atom= 272
# Step= 1611, Dmax= 1.3e-02 nm, Epot= -4.70778e+06 Fmax= 1.90098e+03, atom= 272
# Step= 1613, Dmax= 7.7e-03 nm, Epot= -4.70788e+06 Fmax= 8.07956e+03, atom= 272
# Step= 1614, Dmax= 9.3e-03 nm, Epot= -4.70796e+06 Fmax= 3.92147e+03, atom= 272
# Step= 1616, Dmax= 5.6e-03 nm, Epot= -4.70800e+06 Fmax= 3.27112e+03, atom= 272
# Step= 1617, Dmax= 6.7e-03 nm, Epot= -4.70805e+06 Fmax= 5.38411e+03, atom= 272
# Step= 1618, Dmax= 8.0e-03 nm, Epot= -4.70810e+06 Fmax= 4.97737e+03, atom= 272
# Step= 1619, Dmax= 9.6e-03 nm, Epot= -4.70815e+06 Fmax= 7.48230e+03, atom= 272
# Step= 1620, Dmax= 1.2e-02 nm, Epot= -4.70821e+06 Fmax= 7.44137e+03, atom= 272
# Step= 1621, Dmax= 1.4e-02 nm, Epot= -4.70822e+06 Fmax= 1.04978e+04, atom= 272
# Step= 1622, Dmax= 1.7e-02 nm, Epot= -4.70826e+06 Fmax= 1.09985e+04, atom= 272
# Step= 1624, Dmax= 1.0e-02 nm, Epot= -4.70840e+06 Fmax= 1.88787e+03, atom= 272
# Step= 1625, Dmax= 1.2e-02 nm, Epot= -4.70846e+06 Fmax= 1.35469e+04, atom= 272
# Step= 1626, Dmax= 1.4e-02 nm, Epot= -4.70863e+06 Fmax= 5.01878e+03, atom= 272
# Step= 1628, Dmax= 8.6e-03 nm, Epot= -4.70866e+06 Fmax= 6.11543e+03, atom= 272
# Step= 1629, Dmax= 1.0e-02 nm, Epot= -4.70870e+06 Fmax= 7.27250e+03, atom= 272
# Step= 1630, Dmax= 1.2e-02 nm, Epot= -4.70872e+06 Fmax= 8.76645e+03, atom= 272
# Step= 1631, Dmax= 1.5e-02 nm, Epot= -4.70875e+06 Fmax= 1.05109e+04, atom= 272
# Step= 1632, Dmax= 1.8e-02 nm, Epot= -4.70876e+06 Fmax= 1.25921e+04, atom= 272
# Step= 1633, Dmax= 2.1e-02 nm, Epot= -4.70877e+06 Fmax= 1.51709e+04, atom= 272
# Step= 1635, Dmax= 1.3e-02 nm, Epot= -4.70898e+06 Fmax= 1.51189e+03, atom= 272
# Step= 1636, Dmax= 1.5e-02 nm, Epot= -4.70906e+06 Fmax= 1.85498e+04, atom= 272
# Step= 1637, Dmax= 1.9e-02 nm, Epot= -4.70936e+06 Fmax= 5.47277e+03, atom= 272
# Step= 1639, Dmax= 1.1e-02 nm, Epot= -4.70940e+06 Fmax= 8.92824e+03, atom= 272
# Step= 1640, Dmax= 1.3e-02 nm, Epot= -4.70946e+06 Fmax= 8.31968e+03, atom= 272
# Step= 1642, Dmax= 8.0e-03 nm, Epot= -4.70955e+06 Fmax= 2.02579e+03, atom= 272
# Step= 1643, Dmax= 9.6e-03 nm, Epot= -4.70963e+06 Fmax= 1.03587e+04, atom= 272
# Step= 1644, Dmax= 1.2e-02 nm, Epot= -4.70975e+06 Fmax= 4.54184e+03, atom= 272
# Step= 1646, Dmax= 6.9e-03 nm, Epot= -4.70979e+06 Fmax= 4.39328e+03, atom= 272
# Step= 1647, Dmax= 8.3e-03 nm, Epot= -4.70983e+06 Fmax= 6.35215e+03, atom= 272
# Step= 1648, Dmax= 1.0e-02 nm, Epot= -4.70989e+06 Fmax= 6.51714e+03, atom= 272
# Step= 1649, Dmax= 1.2e-02 nm, Epot= -4.70993e+06 Fmax= 8.95354e+03, atom= 272
# Step= 1650, Dmax= 1.4e-02 nm, Epot= -4.70997e+06 Fmax= 9.58428e+03, atom= 272
# Step= 1652, Dmax= 8.6e-03 nm, Epot= -4.71007e+06 Fmax= 1.53222e+03, atom= 272
# Step= 1653, Dmax= 1.0e-02 nm, Epot= -4.71018e+06 Fmax= 1.17752e+04, atom= 272
# Step= 1654, Dmax= 1.2e-02 nm, Epot= -4.71032e+06 Fmax= 4.23999e+03, atom= 272
# Step= 1656, Dmax= 7.4e-03 nm, Epot= -4.71036e+06 Fmax= 5.36154e+03, atom= 272
# Step= 1725, Dmax= 1.0e-02 nm, Epot= -4.71439e+06 Fmax= 7.50556e+03, atom= 272
# Step= 1726, Dmax= 1.2e-02 nm, Epot= -4.71444e+06 Fmax= 8.42633e+03, atom= 272
# Step= 1727, Dmax= 1.5e-02 nm, Epot= -4.71444e+06 Fmax= 1.07188e+04, atom= 272
# Step= 1728, Dmax= 1.8e-02 nm, Epot= -4.71445e+06 Fmax= 1.22290e+04, atom= 272
# Step= 1730, Dmax= 1.1e-02 nm, Epot= -4.71461e+06 Fmax= 1.52473e+03, atom= 272
# Step= 1731, Dmax= 1.3e-02 nm, Epot= -4.71467e+06 Fmax= 1.49593e+04, atom= 272
# Step= 1732, Dmax= 1.5e-02 nm, Epot= -4.71489e+06 Fmax= 4.86032e+03, atom= 272
# Step= 1734, Dmax= 9.2e-03 nm, Epot= -4.71492e+06 Fmax= 7.02416e+03, atom= 272
# Step= 1735, Dmax= 1.1e-02 nm, Epot= -4.71497e+06 Fmax= 7.26429e+03, atom= 272
# Step= 1736, Dmax= 1.3e-02 nm, Epot= -4.71499e+06 Fmax= 9.85745e+03, atom= 272
# Step= 1737, Dmax= 1.6e-02 nm, Epot= -4.71503e+06 Fmax= 1.07185e+04, atom= 272
# Step= 1739, Dmax= 9.6e-03 nm, Epot= -4.71517e+06 Fmax= 1.63618e+03, atom= 272
# Step= 1740, Dmax= 1.1e-02 nm, Epot= -4.71524e+06 Fmax= 1.32233e+04, atom= 272
# Step= 1741, Dmax= 1.4e-02 nm, Epot= -4.71541e+06 Fmax= 4.56594e+03, atom= 272
# Step= 1743, Dmax= 8.3e-03 nm, Epot= -4.71546e+06 Fmax= 6.10268e+03, atom= 272
# Step= 1744, Dmax= 9.9e-03 nm, Epot= -4.71548e+06 Fmax= 6.68040e+03, atom= 272
# Step= 1745, Dmax= 1.2e-02 nm, Epot= -4.71550e+06 Fmax= 8.68176e+03, atom= 272
# Step= 1746, Dmax= 1.4e-02 nm, Epot= -4.71554e+06 Fmax= 9.73010e+03, atom= 272
# Step= 1747, Dmax= 1.7e-02 nm, Epot= -4.71554e+06 Fmax= 1.23933e+04, atom= 272
# Step= 1749, Dmax= 1.0e-02 nm, Epot= -4.71569e+06 Fmax= 8.93815e+02, atom= 272
#
# writing lowest energy coordinates.
#
# Steepest Descents converged to Fmax < 1000 in 1750 steps
# Potential Energy  = -4.7156855e+06
# Maximum force     =  8.9381500e+02 on atom 272
# Norm of force     =  1.0976084e+01
#
# GROMACS reminds you: "Remember, being healthy is basically dying as slowly as possible." (Ricky Gervais)

# %% [markdown]
# The -v flag is for the impatient: it makes `gmx mdrun` verbose, such that it prints its progress to the screen at every step. Never use this flag if run in background, on a HPC center or on a local cluster, it prints unnecessary data in the standard output file.
# The -deffnm flag will define the file names of the input and output. So, if you did not name your grompp output "em.tpr," you will have to explicitly specify its name with the `gmx mdrun` -s flag.

# %% [markdown]
# *Note: if you do not want to wait, but look at some of the results directly, copy the data from the /reference directory into the current directory. To do this from within this notebook, remove the comment characters (#) in the following cell*

# %%
## ONLY execute the lines below if you do not want to run and wait for the simulation to finish
# !cp reference/em_charmm.edr em.edr
# !cp reference/em_charmm.gro em.gro

# %% [markdown]
# ## Determining if the run was successful

# %% [markdown]
# There are two very important factors to evaluate to determine if EM was successful.
#
# The first is the potential energy (printed at the end of the EM process, even without -v). Epot should be negative and (for a simple protein in water) on the order of 100000 kJ/mol, depending on the system size and number of water molecules
#
# The second important feature is the maximum force, Fmax, the target for which was set in minim.mdp - "emtol = 1000.0" - indicating a target Fmax of no greater than 1000 kJ/(mol nm). It is possible to arrive at a reasonable Epot with Fmax > emtol. If this happens, your system may not be stable enough for simulation. Evaluate why it may be happening, and perhaps change your minimization parameters (integrator, emstep, etc).

# %% [markdown]
# ## Analysing the run results

# %% [markdown]
# Let's do a bit of analysis. The em.edr file contains all of the energy terms that GROMACS collects during EM. You can analyze any .edr file using the GROMACS energy module.

# %% [markdown]
# To analyse or visualize simulation data in python or jupyter notebooks, we can output a simplified xvg format from gmx-analysis tools with the option `-xvg none`

# %%
# !printf "Potential\n0\n" | gmx energy -f em.edr -o potential.xvg -xvg none
# Out:
#                 :-) GROMACS - gmx energy, 2023.3-conda_forge (-:
#
# Executable:   /home/thangavelucs/anaconda3/envs/md-intro-tutorial/bin.AVX2_256/gmx
# Data prefix:  /home/thangavelucs/anaconda3/envs/md-intro-tutorial
# Working dir:  /home/thangavelucs/MD_Intro_Tutorial/md-intro-tutorial-main/kras_data
# Command line:
#   gmx energy -f em.edr -o potential.xvg -xvg none
#
# Opened em.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  U-B              3  Proper-Dih.      4  Improper-Dih.
#   5  CMAP-Dih.        6  LJ-14            7  Coulomb-14       8  LJ-(SR)
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Pressure
#  13  Constr.-rmsd    14  Vir-XX          15  Vir-XY          16  Vir-XZ
#  17  Vir-YX          18  Vir-YY          19  Vir-YZ          20  Vir-ZX
#  21  Vir-ZY          22  Vir-ZZ          23  Pres-XX         24  Pres-XY
#  25  Pres-XZ         26  Pres-YX         27  Pres-YY         28  Pres-YZ
#  29  Pres-ZX         30  Pres-ZY         31  Pres-ZZ         32  #Surf*SurfTen
#  33  T-rest
#
# Last energy frame read 1385 time 1749.000
#
# Statistics over 1750 steps [ 0.0000 through 1749.0000 ps ], 1 data sets
# All statistics are over 1386 points (frames)
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Potential                -4.58961e+06      64000     164263    -425162  (kJ/mol)
#
# GROMACS reminds you: "Humans are allergic to change. They love to say, 'We've always done it this way.' I try to fight that. That's why I have a clock on my wall that runs counter-clockwise." (Grace Hopper)

# %% [markdown]
# You will be shown the average of Epot, and a file called "potential.xvg" will be written. To plot this data file, you can use the script below. The resulting plot should show a steady convergence of Epot.

# %%
import pandas as pd
df = pd.read_csv('potential.xvg', sep='\s+', header=None, names=['step','energy'])
df.plot('step')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# /tmp/thangavelucs/ipykernel_797680/2802870336.py:2: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv('potential.xvg', sep='\s+', header=None, names=['step','energy'])
# <Axes: xlabel='step'>

# %% [markdown]
# Now that our system is at an energy minimum, we can begin real dynamics.

# %% [markdown]
# # Position restraints

# %% [markdown]
# EM ensured that we have a reasonable starting structure, in terms of geometry and solvent orientation. To begin real dynamics, we must equilibrate the solvent and ions around the protein. If we were to attempt unrestrained dynamics at this point, the system may collapse. The reason is that the solvent is mostly optimized within itself, and not necessarily with the solute, and ions are randomly placed by replacing water molecules.

# %% [markdown]
# Remember that posre.itp file that pdb2gmx generated a long time ago? We're going to use it now. The purpose of posre.itp is to apply a position restraining force on the heavy atoms of the protein (anything that is not a hydrogen). Movement is permitted, but only after overcoming a substantial energy penalty. The utility of position restraints is that they allow us to relax our solvent and ions around our protein, without the added variable of structural changes in the protein. The origin of the position restraints (the coordinates at which the restraint potential is zero) is provided via a coordinate file passed to the -r option of grompp. Depending from the protein and ion types, this process may also be in the order nanoseconds.

# %% [markdown]
# To use position restraints we need to add \"define = -DPOSRES\" to the simulation parameter file, .mdp, (more details on the simulation parameters below). Have a look at the .mdp file for this run:

# %%
# !head -5 input/nvt-charmm.mdp
# Out:
# title                   = CHARMM NVT equilibration
# define                  = -DPOSRES  ; position restrain the protein
#
# ; Parameters describing what to do, when to stop and what to save
# integrator              = md        ; leap-frog integrator

# %% [markdown]
# When using position restraints, a file with restraint coordinates must be supplied with -r to gmx grompp (see below). It can be the same file as supplied for -c.

# %% [markdown]
# # Equilibration run - temperature

# %% [markdown]
# EM ensured that we have a reasonable starting structure, in terms of geometry and solvent orientation. Now the system needs to be brought to the temperature we wish to simulate and establish the proper orientation about the solute (the protein). After we arrive at the correct temperature (based on kinetic energies), we will apply pressure to the system until it reaches the proper density.

# %% [markdown]
# Equilibration is often conducted in two phases. The first phase is conducted under an NVT ensemble (constant Number of particles, Volume, and Temperature). This ensemble is also referred to as "isothermal-isochoric" or "canonical." The timeframe for such a procedure is dependent upon the contents of the system. Typically, 100-200 ps should suffice, and we will conduct a 100-ps NVT equilibration for this exercise. Depending on your machine, this may take a while (just under an hour if run in parallel on 16 cores or so).

# %% [markdown]
# We will call grompp and mdrun just as we did at the EM step, but this time with the energy minimised structure as input and a different .mdp file for the run. Have a look at the input file for this run:

# %%
# !cat input/nvt-charmm.mdp

# %% [markdown]
# Instead of energy tolerance, we now give time a step size and a number of steps. Furthermore, we need to set a temperature. Now, we're good to run. Take note of a few parameters in the .mdp file:
#
# - `gen_vel = yes`: Initiates velocity generation. Using different random seeds (gen_seed) gives different initial velocities, and thus multiple (different) simulations can be conducted from the same starting structure.
# - `tcoupl = V-rescale`: The velocity rescaling thermostat is an improvement upon the Berendsen weak coupling method, which did not reproduce a correct kinetic ensemble.
# - `pcoupl = no`: Pressure coupling is not applied.
#
# A full explanation of the parameters used can be found in the GROMACS [manual](http://manual.gromacs.org/documentation/current/user-guide/mdp-options.html), in addition to the comments provided.

# %% [markdown]
# Now, we're good to run.

# %% [markdown]
# # stopped here

# %%
# !gmx grompp -f nvt-charmm.mdp -c em.gro -r em.gro -p kras_topol.top -o nvt.tpr 
# !gmx mdrun -ntmpi 1 -v -deffnm nvt
# Out:
#                 :-) GROMACS - gmx grompp, 2023.3-conda_forge (-:
#
# Executable:   /home/thangavelucs/anaconda3/envs/md-intro-tutorial/bin.AVX2_256/gmx
# Data prefix:  /home/thangavelucs/anaconda3/envs/md-intro-tutorial
# Working dir:  /home/thangavelucs/MD_Intro_Tutorial/md-intro-tutorial-main/kras_data
# Command line:
#   gmx grompp -f nvt-charmm.mdp -c em.gro -r em.gro -p kras_topol.top -o nvt.tpr
#
# Ignoring obsolete mdp entry 'title'
# Setting the LD random seed to -109052359
#
# Generated 167799 of the 167910 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 1
#
# Generated 117432 of the 167910 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# Excluding 3 bonded neighbours molecule type 'NA'
#
# turning H bonds into constraints...
#
# Excluding 3 bonded neighbours molecule type 'CL'
#
# turning H bonds into constraints...
#
# Setting gen_seed to -1168640004
#
# Velocities were taken from a Maxwell distribution at 300 K
#
# NOTE 1 [file kras_topol.top, line 3618]:
#   In moleculetype 'Protein' 205 atoms are not bound by a potential or
#   constraint to any other atom in the same moleculetype. Although
#   technically this might not cause issues in a simulation, this often means
#   that the user forgot to add a bond/potential/constraint or put multiple
#   molecules in the same moleculetype definition by mistake. Run with -v to
#   get information for each atom.
#
# Analysing residue names:
# There are:    18    Protein residues
# There are:   785        Ion residues
# There are: 89415      Water residues
# Analysing Protein...
# Number of degrees of freedom in T-Coupling group System is 539654.00
#
# The largest distance between excluded atoms is 0.416 nm between atom 66 and 73
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 300 K
#
# Calculated rlist for 1x1 atom pair-list as 1.235 nm, buffer size 0.035 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.200 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# NOTE 2 [file nvt-charmm.mdp]:
#   Removing center of mass motion in the presence of position restraints
#   might cause artifacts. When you are using position restraints to
#   equilibrate a macro-molecule, the artifacts are usually negligible.
#
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 108x108x108, spacing 0.146 0.146 0.146
#
# Estimate for the relative computational load of the PME mesh part: 0.17
#
# This run will generate roughly 21 Mb of data
#
# There were 2 NOTEs
#
# GROMACS reminds you: "Never Get a Chance to Kick Ass" (The Amps)
#
#                 :-) GROMACS - gmx mdrun, 2023.3-conda_forge (-:
#
# Executable:   /home/thangavelucs/anaconda3/envs/md-intro-tutorial/bin.AVX2_256/gmx
# Data prefix:  /home/thangavelucs/anaconda3/envs/md-intro-tutorial
# Working dir:  /home/thangavelucs/MD_Intro_Tutorial/md-intro-tutorial-main/kras_data
# Command line:
#   gmx mdrun -ntmpi 1 -v -deffnm nvt
#
# Compiled SIMD is AVX2_256, but CPU also supports AVX_512 (see log).
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file nvt.tpr, VERSION 2023.3-conda_forge (single precision)
# Changing nstlist from 10 to 80, rlist from 1.2 to 1.323
#
#
# Using 1 MPI thread
#
# Non-default thread affinity set, disabling internal thread affinity
#
# Using 1 OpenMP thread
#
# starting mdrun 'Protein in water t=   0.00000 step= 0'
# 50000 steps,    100.0 ps.
# step 49900, remaining wall clock time:    67 s          nish Tue Jun  4 14:02:42 20249600, will finish Tue Jun  4 13:48:30 202447700, will finish Tue Jun  4 13:19:54 2024
# Writing final coordinates.
# step 50000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:    33772.347    33772.349      100.0
#                          9h22:52
#                  (ns/day)    (hour/ns)
# Performance:        0.256       93.810
#
# GROMACS reminds you: "Suzy is a headbanger, her mother is a geek" (The Ramones)

# %% [markdown]
# Your computer should be working at full speed now to finish this simulation; it should be done in 5 to 10 minutes.

# %% [markdown]
# *Note: if you do not want to wait, but look at some of the results directly, copy the data from the /reference directory into the current directory. To do this from within this notebook, remove the comment characters (#) in the following cell*

# %%
## ONLY execute the lines below if you do not want to run and wait for the simulation to finish
#!cp reference/nvt_charmm.edr nvt.edr
#!cp reference/nvt_charmm.gro nvt.gro
#!cp reference/nvt_charmm.cpt nvt.cpt

# %% [markdown]
# Let's analyze the temperature progression, again using gmx energy:

# %%
# !echo "Temperature" | gmx energy -f nvt.edr -o temperature.xvg -xvg none -b 20
# Out:
#                 :-) GROMACS - gmx energy, 2023.3-conda_forge (-:
#
# Executable:   /home/thangavelucs/anaconda3/envs/md-intro-tutorial/bin.AVX2_256/gmx
# Data prefix:  /home/thangavelucs/anaconda3/envs/md-intro-tutorial
# Working dir:  /home/thangavelucs/MD_Intro_Tutorial/md-intro-tutorial-main/kras_data
# Command line:
#   gmx energy -f nvt.edr -o temperature.xvg -xvg none -b 20
#
# Opened nvt.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  U-B              3  Proper-Dih.      4  Improper-Dih.
#   5  CMAP-Dih.        6  LJ-14            7  Coulomb-14       8  LJ-(SR)
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Position-Rest.  12  Potential
#  13  Kinetic-En.     14  Total-Energy    15  Conserved-En.   16  Temperature
#  17  Pressure        18  Constr.-rmsd    19  Vir-XX          20  Vir-XY
#  21  Vir-XZ          22  Vir-YX          23  Vir-YY          24  Vir-YZ
#  25  Vir-ZX          26  Vir-ZY          27  Vir-ZZ          28  Pres-XX
#  29  Pres-XY         30  Pres-XZ         31  Pres-YX         32  Pres-YY
#  33  Pres-YZ         34  Pres-ZX         35  Pres-ZY         36  Pres-ZZ
#  37  #Surf*SurfTen   38  T-System        39  Lamb-System
#
# Last energy frame read 100 time  100.000
#
# Statistics over 40001 steps [ 20.0000 through 100.0000 ps ], 1 data sets
# All statistics are over 401 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Temperature                 299.974      0.075   0.541518   0.348328  (K)
#
# GROMACS reminds you: "I do not believe continuum electrostatics" (Arieh Warshel, Nobel lecture 2013)

# %%
import pandas as pd
df = pd.read_csv('temperature.xvg', sep='\s+', header=None, names=['time','temperature'])
df.plot('time')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# /tmp/thangavelucs/ipykernel_3071773/1368634232.py:2: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv('temperature.xvg', sep='\s+', header=None, names=['time','temperature'])
# <Axes: xlabel='time'>

# %% [markdown]
# From the plot, it is clear that the temperature of the system quickly reaches the target value (300 K), and remains stable over the remainder of the equilibration. For this system, an equilibration period (on the order of 50 ps) may be adequate.

# %% [markdown]
# # Equilibration run - pressure

# %% [markdown]
# The previous step, NVT equilibration, stabilized the temperature of the system. Prior to data collection, we must also stabilize the pressure (and thus also the density) of the system. Equilibration of pressure is conducted under an NPT ensemble, wherein the Number of particles, Pressure, and Temperature are all constant. The ensemble is also called the "isothermal-isobaric" ensemble, and most closely resembles experimental conditions.
#
# The .mdp file used for a 100-ps NPT equilibration can be found here. It is not drastically different from the parameter file used for NVT equilibration. Note the addition of the pressure coupling section. Berendsen barostat is used for this equilibation phase.

# %%
# !cat npt-charmm.mdp
# Out:
# title                   = CHARMM NPT equilibration
# define                  = -DPOSRES  ; position restrain the protein
#
# ; Parameters describing what to do, when to stop and what to save
# integrator              = md        ; leap-frog integrator
# dt                      = 0.002     ; 2 fs
# nsteps                  = 50000     ; 2 * 50000 = 100 ps
# nstenergy               = 500       ; save energy and temperature every 1.0 ps
#
# ; periodic boundary condition
# pbc                     = xyz       ;
#
# continuation            = yes
#
# ; Pressure coupling is on
# pcoupl                  = C-rescale             ; Pressure coupling on in NPT
# pcoupltype              = isotropic             ; uniform scaling of box vectors
# tau_p                   = 5.0                   ; time constant, in ps
# ref_p                   = 1.0                   ; reference pressure, in bar
# compressibility         = 4.5e-5                ; isothermal compressibility of water, bar^-1
# refcoord_scaling        = com
#
# ; Keep system temperature fluctuating physically correct
# tcoupl                  = V-rescale           ; modified Berendsen thermostat
# tc-grps                 = system   ; coupling groups
# tau_t                   = 1.0      ; time constant, in ps
# ref_t                   = 300      ; reference temperature, one for each group, in K
#
# ; Settings that make sure we run with parameters in harmony with the selected force-field
# constraints             = h-bonds   ; bonds involving H are constrained
# rcoulomb                = 1.2       ; short-range electrostatic cutoff (in nm)
# rvdw                    = 1.2       ; short-range van der Waals cutoff (in nm)
# vdw-modifier            = Force-switch ;  specific CHARMM
# rvdw_switch             = 1.0       ;
# DispCorr                = no        ; account for cut-off vdW scheme -
# ;in case of CHARMM DispCorr = EnerPres only for monolayers
# coulombtype             = PME       ; Particle Mesh Ewald for long-range electrostatics
# fourierspacing          = 0.15     ; grid spacing for FFT

# %% [markdown]
# A few other changes:
#
# - `continuation = yes`: We are continuing the simulation from the NVT equilibration phase
# - `gen_vel = no`: Velocities are read from the trajectory (see below)
#
# We will call grompp and mdrun just as we did for NVT equilibration. Note that we are now including the -t flag to include the checkpoint file from the NVT equilibration; this file contains all the necessary state variables to continue our simulation. To conserve the velocities produced during NVT, we must include the final coordinate file (output) of the NVT simulation using the option (-c).

# %%
# !gmx grompp -f npt-charmm.mdp -c nvt.gro -r nvt.gro -t nvt.cpt -p kras_topol.top -o npt.tpr
# Out:
#                 :-) GROMACS - gmx grompp, 2023.3-conda_forge (-:
#
# Executable:   /home/thangavelucs/anaconda3/envs/md-intro-tutorial/bin.AVX2_256/gmx
# Data prefix:  /home/thangavelucs/anaconda3/envs/md-intro-tutorial
# Working dir:  /home/thangavelucs/MD_Intro_Tutorial/md-intro-tutorial-main/kras_data
# Command line:
#   gmx grompp -f npt-charmm.mdp -c nvt.gro -r nvt.gro -t nvt.cpt -p kras_topol.top -o npt.tpr
#
# Ignoring obsolete mdp entry 'title'
# Setting the LD random seed to -1180289
#
# Generated 167799 of the 167910 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 1
#
# Generated 117432 of the 167910 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# Excluding 3 bonded neighbours molecule type 'NA'
#
# turning H bonds into constraints...
#
# Excluding 3 bonded neighbours molecule type 'CL'
#
# turning H bonds into constraints...
#
# The center of mass of the position restraint coord's is 10.814 10.729  4.991
#
# The center of mass of the position restraint coord's is 10.814 10.729  4.991
#
# NOTE 1 [file kras_topol.top, line 3618]:
#   In moleculetype 'Protein' 205 atoms are not bound by a potential or
#   constraint to any other atom in the same moleculetype. Although
#   technically this might not cause issues in a simulation, this often means
#   that the user forgot to add a bond/potential/constraint or put multiple
#   molecules in the same moleculetype definition by mistake. Run with -v to
#   get information for each atom.
#
# Analysing residue names:
# There are:    18    Protein residues
# There are:   785        Ion residues
# There are: 89415      Water residues
# Analysing Protein...
# Number of degrees of freedom in T-Coupling group System is 539654.00
#
# The largest distance between excluded atoms is 0.418 nm between atom 66 and 73
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 300 K
#
# Calculated rlist for 1x1 atom pair-list as 1.235 nm, buffer size 0.035 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.200 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# NOTE 2 [file npt-charmm.mdp]:
#   Removing center of mass motion in the presence of position restraints
#   might cause artifacts. When you are using position restraints to
#   equilibrate a macro-molecule, the artifacts are usually negligible.
#
#
# Reading Coordinates, Velocities and Box size from old trajectory
#
# Will read whole trajectory
# Last frame         -1 time  100.000
#
# Using frame at t = 100 ps
#
# Starting time for run is 0 ps
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 108x108x108, spacing 0.146 0.146 0.146
#
# Estimate for the relative computational load of the PME mesh part: 0.17
#
# This run will generate roughly 21 Mb of data
#
# There were 2 NOTEs
#
# GROMACS reminds you: "Any one who considers arithmetical methods of producing random digits is, of course, in a state of sin." (John von Neumann)

# %% [markdown]
# Now we'll start an MD simulation just like before - this one will take a few minutes; that's why it is commented out. Go ahead run it if you want to generate your own data.

# %%
# !gmx mdrun -ntmpi 1 -v -deffnm npt
# Out:
#                 :-) GROMACS - gmx mdrun, 2023.3-conda_forge (-:
#
# Executable:   /home/thangavelucs/anaconda3/envs/md-intro-tutorial/bin.AVX2_256/gmx
# Data prefix:  /home/thangavelucs/anaconda3/envs/md-intro-tutorial
# Working dir:  /home/thangavelucs/MD_Intro_Tutorial/md-intro-tutorial-main/kras_data
# Command line:
#   gmx mdrun -ntmpi 1 -v -deffnm npt
#
# Compiled SIMD is AVX2_256, but CPU also supports AVX_512 (see log).
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file npt.tpr, VERSION 2023.3-conda_forge (single precision)
# Changing nstlist from 10 to 80, rlist from 1.2 to 1.323
#
#
# Using 1 MPI thread
#
# Non-default thread affinity set, disabling internal thread affinity
#
# Using 1 OpenMP thread
#
# starting mdrun 'Protein in water t=   0.00000 step= 0'
# 50000 steps,    100.0 ps.
# step 49900, remaining wall clock time:    57 s          ill finish Wed Jun  5 04:36:44 2024, will finish Wed Jun  5 04:40:00 202417700, will finish Wed Jun  5 04:39:24 2024
# Writing final coordinates.
# step 50000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:    28924.588    28924.590      100.0
#                          8h02:04
#                  (ns/day)    (hour/ns)
# Performance:        0.299       80.344
#
# GROMACS reminds you: "Space May Be the Final Frontier, But It's Made in a Hollywood Basement" (Red Hot Chili Peppers)

# %% [markdown]
# If the simulation takes too long to run for this tutorial, you may use the provided data by copying it to the current directory. But remember that you can always check/analyse the output files while the simulation is still running.

# %%
##ONLY execute the lines below if you do not want to run and wait for the simulation to finish
#!cp reference/npt_charmm.edr npt.edr
#!cp reference/npt_charmm.gro npt.gro
#!cp reference/npt_charmm.cpt npt.cpt

# %% [markdown]
# Let's analyze the pressure progression, again using energy:

# %%
# !echo "Pressure" | gmx energy -f npt.edr -o pressure.xvg -xvg none
# Out:
#                 :-) GROMACS - gmx energy, 2023.3-conda_forge (-:
#
# Executable:   /home/thangavelucs/anaconda3/envs/md-intro-tutorial/bin.AVX2_256/gmx
# Data prefix:  /home/thangavelucs/anaconda3/envs/md-intro-tutorial
# Working dir:  /home/thangavelucs/MD_Intro_Tutorial/md-intro-tutorial-main/kras_data
# Command line:
#   gmx energy -f npt.edr -o pressure.xvg -xvg none
#
# Opened npt.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  U-B              3  Proper-Dih.      4  Improper-Dih.
#   5  CMAP-Dih.        6  LJ-14            7  Coulomb-14       8  LJ-(SR)
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Position-Rest.  12  Potential
#  13  Kinetic-En.     14  Total-Energy    15  Conserved-En.   16  Temperature
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
# Last energy frame read 100 time  100.000
#
# Statistics over 50001 steps [ 0.0000 through 100.0000 ps ], 1 data sets
# All statistics are over 501 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Pressure                   -42.8407         40    111.059    214.484  (bar)
#
# GROMACS reminds you: "Been There, Done It" (Beavis and Butthead)

# %%
import pandas as pd
df = pd.read_csv('pressure.xvg', sep='\s+', header=None, names=['time','pressure'])
df.plot('time')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# /tmp/thangavelucs/ipykernel_3004912/1477187075.py:2: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv('pressure.xvg', sep='\s+', header=None, names=['time','pressure'])
# <Axes: xlabel='time'>

# %% [markdown]
# The pressure value fluctuates widely over the course of the 100-ps equilibration phase, but this behavior is not unexpected. The reference pressure was set to 1 bar, so is this outcome acceptable? Pressure is a quantity that fluctuates widely over the course of an MD simulation, as is clear from the large root-mean-square fluctuation (in the order of 100 bar), so statistically speaking, one cannot distinguish a difference between the obtained average and the target/reference value (1 bar).
#
# Let's take a look at density as well using energy.

# %%
# !echo "Density" | gmx energy -f npt.edr -o density.xvg -xvg none
# Out:
#                 :-) GROMACS - gmx energy, 2023.3-conda_forge (-:
#
# Executable:   /home/thangavelucs/anaconda3/envs/md-intro-tutorial/bin.AVX2_256/gmx
# Data prefix:  /home/thangavelucs/anaconda3/envs/md-intro-tutorial
# Working dir:  /home/thangavelucs/MD_Intro_Tutorial/md-intro-tutorial-main/kras_data
# Command line:
#   gmx energy -f npt.edr -o density.xvg -xvg none
#
# Opened npt.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  U-B              3  Proper-Dih.      4  Improper-Dih.
#   5  CMAP-Dih.        6  LJ-14            7  Coulomb-14       8  LJ-(SR)
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Position-Rest.  12  Potential
#  13  Kinetic-En.     14  Total-Energy    15  Conserved-En.   16  Temperature
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
# Last energy frame read 100 time  100.000
#
# Statistics over 50001 steps [ 0.0000 through 100.0000 ps ], 1 data sets
# All statistics are over 501 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Density                     1016.19        2.4    6.34393     13.089  (kg/m^3)
#
# GROMACS reminds you: "My Head Goes Pop Pop Pop Pop Pop" (F. Black)

# %%
import pandas as pd
df = pd.read_csv('density.xvg', sep='\s+', header=None, names=['time','density'])
df.plot('time')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# /tmp/thangavelucs/ipykernel_3004912/325656315.py:2: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv('density.xvg', sep='\s+', header=None, names=['time','density'])
# <Axes: xlabel='time'>

# %% [markdown]
# The average value is close to the experimental value of 1000 kg m-3 and the expected density of the TIP3P model of 1001 kg m-3. The parameters for the TIP3P water model closely replicate experimental values for water. The density values are very stable over time, indicating that the system is well-equilibrated now with respect to pressure and density.
#
# Please note: Pressure-related terms are slow to converge, and thus you may have to run NPT equilibration slightly longer than is specified here.

# %% [markdown]
# # The "production" run

# %% [markdown]
# Upon completion of the two equilibration phases, the system is now well-equilibrated at the desired temperature and pressure. We are now ready to release the position restraints and run production MD for data collection. The process is just like we have seen before, as we will make use of the checkpoint file (which in this case now contains preserve pressure coupling information) to grompp. We will run a 1-ns MD simulation. Note we have explictly add a section that controls the output frequency in log file (.log), energy file (.edr), in the trajcotry file (.trr) and the compress trajectory file (.xtc).

# %%
# !cat md-charmm.mdp
# Out:
# title                   = CHARMM NPT
#
# ; Parameters describing what to do, when to stop and what to save
# integrator              = md        ; leap-frog integrator
# dt                      = 0.002     ; 2 fs
# nsteps                  = 500000     ;  1000 ps = 1 ns
#
# ; periodic boundary condition
# pbc                     = xyz       ;
#
# continuation            = yes
#
# ; Output control - output frequency in steps
# ; Output frequency for  output trajctory file ,trr
# nstxout                  = 0       ; for writing coords (x)
# nstvout                  = 0       ; for writing velocities (v)
# nstfout                  = 0       ; for writing forces (f)
# ; Output frequency for energies to log file and energy file
# nstlog                   = 1000    ; for writing energies to log file
# nstenergy                = 500     ; for writing energies to edr file
# ; Output frequency and precision for .xtc file
# nstxout-compressed       = 2500    ; for writing coords (x)
#
# ; Pressure coupling is on
# pcoupl                  = C-rescale               ; Pressure coupling on in NPT
# pcoupltype              = isotropic             ; uniform scaling of box vectors
# tau_p                   = 5.0                   ; time constant, in ps
# ref_p                   = 1.0                   ; reference pressure, in bar
# compressibility         = 4.5e-5                ; isothermal compressibility of water, bar^-1
# refcoord_scaling        = com
#
# ; Keep system temperature fluctuating physically correct
# tcoupl                  = V-rescale           ; modified Berendsen thermostat
# tc-grps                 = system ;
# tau_t                   = 1.0    ; time constant, in ps
# ref_t                   = 300    ; reference temperature, one for each group, in K
#
# ; Settings that make sure we run with parameters in harmony with the selected force-field
# constraints             = h-bonds   ; bonds involving H are constrained
# rcoulomb                = 1.2       ; short-range electrostatic cutoff (in nm)
# rvdw                    = 1.2       ; short-range van der Waals cutoff (in nm)
# vdw-modifier            = Force-switch ;  specific CHARMM
# rvdw_switch             = 1.0       ;
# DispCorr                = no        ; account for cut-off vdW scheme -
# ;in case of CHARMM DispCorr = EnerPres only for monolayers
# coulombtype             = PME       ; Particle Mesh Ewald for long-range electrostatics
# fourierspacing          = 0.15     ; grid spacing for FFT

# %% [markdown]
# We use velocity-rescaling temperature coupling as thermostat and stochastic cell rescaling as barostat. A full explanation of the available thermostats and barostats in GROMACS can be found in the manual (see [here](http://manual.gromacs.org/documentation/current/reference-manual/algorithms/molecular-dynamics.html#temperature-coupling) for thermostat and [here](http://manual.gromacs.org/documentation/current/reference-manual/algorithms/molecular-dynamics.html#pressure-coupling) for barostat).
#
# Note, for thermostats and barostats we need to compute temperature or pressure.
#
# `gmx grompp` will print an estimate for generated data and PME load. PME load will dictate how many processors should be dedicated to the PME calculation, and how many for the PP (everything except for PME) calculations. Refer to the [manual](http://manual.gromacs.org/documentation/current/user-guide/mdrun-performance.html#parallelization-schemes) for details.

# %%
# !gmx grompp -f md-charmm.mdp -c npt.gro -t npt.cpt -p kras_topol.top -o md.tpr
# Out:
#                 :-) GROMACS - gmx grompp, 2023.3-conda_forge (-:
#
# Executable:   /home/thangavelucs/anaconda3/envs/md-intro-tutorial/bin.AVX2_256/gmx
# Data prefix:  /home/thangavelucs/anaconda3/envs/md-intro-tutorial
# Working dir:  /home/thangavelucs/MD_Intro_Tutorial/md-intro-tutorial-main/kras_data
# Command line:
#   gmx grompp -f md-charmm.mdp -c npt.gro -t npt.cpt -p kras_topol.top -o md.tpr
#
# Ignoring obsolete mdp entry 'title'
# Setting the LD random seed to -3282034
#
# Generated 167799 of the 167910 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 1
#
# Generated 117432 of the 167910 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# Excluding 3 bonded neighbours molecule type 'NA'
#
# turning H bonds into constraints...
#
# Excluding 3 bonded neighbours molecule type 'CL'
#
# turning H bonds into constraints...
#
# NOTE 1 [file kras_topol.top, line 3618]:
#   In moleculetype 'Protein' 205 atoms are not bound by a potential or
#   constraint to any other atom in the same moleculetype. Although
#   technically this might not cause issues in a simulation, this often means
#   that the user forgot to add a bond/potential/constraint or put multiple
#   molecules in the same moleculetype definition by mistake. Run with -v to
#   get information for each atom.
#
# Analysing residue names:
# There are:    18    Protein residues
# There are:   785        Ion residues
# There are: 89415      Water residues
# Analysing Protein...
# Number of degrees of freedom in T-Coupling group System is 539654.00
#
# The largest distance between excluded atoms is 0.410 nm between atom 66 and 73
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 300 K
#
# Calculated rlist for 1x1 atom pair-list as 1.235 nm, buffer size 0.035 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.200 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# Reading Coordinates, Velocities and Box size from old trajectory
#
# Will read whole trajectory
# Last frame         -1 time  100.000
#
# Using frame at t = 100 ps
#
# Starting time for run is 0 ps
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 104x104x104, spacing 0.150 0.150 0.150
#
# Estimate for the relative computational load of the PME mesh part: 0.16
#
# This run will generate roughly 281 Mb of data
#
# There was 1 NOTE
#
# GROMACS reminds you: "Count the Bubbles In Your Hair" (The Breeders)

# %%
# !gmx mdrun -ntmpi 1 -v -deffnm md
# Out:
#                 :-) GROMACS - gmx mdrun, 2023.3-conda_forge (-:
#
# Executable:   /home/thangavelucs/anaconda3/envs/md-intro-tutorial/bin.AVX2_256/gmx
# Data prefix:  /home/thangavelucs/anaconda3/envs/md-intro-tutorial
# Working dir:  /home/thangavelucs/MD_Intro_Tutorial/md-intro-tutorial-main/kras_data
# Command line:
#   gmx mdrun -ntmpi 1 -v -deffnm md
#
# Compiled SIMD is AVX2_256, but CPU also supports AVX_512 (see log).
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file md.tpr, VERSION 2023.3-conda_forge (single precision)
# Changing nstlist from 10 to 80, rlist from 1.2 to 1.325
#
#
# Using 1 MPI thread
#
# Non-default thread affinity set, disabling internal thread affinity
#
# Using 1 OpenMP thread
#
# starting mdrun 'Protein in water t=   0.00000 step= 0'
# 500000 steps,   1000.0 ps.
# step 6100, will finish Sat Jun  8 23:45:32 20244200, will finish Sun Jun  9 00:05:19 2024

# %% [markdown]
# As before, this run will take some time - probably more than planned for going through this tutorial. As an alternative, use the data provided here

# %%
##ONLY execute the lines below if you do not want to run and wait for the simulation to finish
#!cp reference/md_charmm.log md.log
#!cp reference/md_charmm.edr md.edr
#!cp reference/md_charmm.gro md.gro
#!cp reference/md_charmm.xtc md.xtc

# %% [markdown]
# # Analysis

# %% [markdown]
# Now that we have simulated our protein, we should run some analysis on the system. What types of data are important? This is an important question to ask before running the simulation, so you should have some ideas about the types of data you will want to collect in your own systems. For this tutorial, a few basic tools will be introduced.

# %% [markdown]
# The first tool is [`gmx trjconv`](https://manual.gromacs.org/current/onlinehelp/gmx-trjconv.html), which is used as a post-processing tool to strip out coordinates, correct for periodicity, or manually alter the trajectory (time units, frame frequency, etc). Here you find a suggested workflow for `gmx trjconv` [link](https://manual.gromacs.org/2021/user-guide/terminology.html?highlight=periodic%20boundary). This exercise, we will use `gmx trjconv` to account for any periodicity in the system. The protein will diffuse through the unit cell, and may appear "broken" or may "jump" across to the other side of the box. To account for such actions, issue the following:

# %%
# !printf "1\n1\n" | gmx trjconv -s md.tpr -f md.xtc -o md_center.xtc -center -pbc mol

# %%
# !printf "1\n1\n" | gmx trjconv -s md.tpr -f md.xtc -o test_output.xtc -center -pbc mol

# %% [markdown]
# Select 1 ("Protein") as the group to be centered and 1 ("Protein") for output. We will conduct all our analyses on this "corrected" trajectory. Let's look at so obtained trajcetory using nglview.

# %% [markdown]
# # THE VIDEO SECTION (needs xtc and gro)

# %%
# !pwd
#!ls -lh
# Out:
# /home/thangavelucs/MD_Intro_Tutorial/md-intro-tutorial-main/kras_data

# %%
import nglview as ng 
import mdtraj as md
traj = md.load("raswt.xtc", top="raswt.gro")
view = ng.show_mdtraj(traj)
view
# Out:
# NGLWidget(max_frame=1000)

# %% [markdown]
# Note, the protein should never interact with its periodic image (minimum image convention), otherwise the forces calculated will be spurious. To calculate the distance between the protein and its periodic image, we use the tool [`gmx mindist`](https://manual.gromacs.org/current/onlinehelp/gmx-mindist.html) with the option -pi.

# %%
# !printf "1\n" | gmx mindist -s md.tpr -f md_center.xtc -pi -od mindist.xvg 
#!xmgrace mindist.xvg

# %% [markdown]
# The distance between the protein and its periodic image should not be smaller than the cut-off used to describe non-bonded interactions.

# %% [markdown]
# Now let's look at structural stability. GROMACS has a built-in utility for RMSD calculations called [`gmx rms`](https://manual.gromacs.org/current/onlinehelp/gmx-rms.html). To calculate RMSD relative to the crystal structure, issue this command:

# %%
# !printf "4\n1\n" | gmx rms -s em.tpr -f md_center.xtc -o rmsd_xray.xvg -tu ns -xvg none

# %% [markdown]
# Choose 4 ("Backbone") for both the least-squares fit and the group for RMSD calculation. The -tu flag will output the results in terms of ns, even though the trajectory was written in ps. This is done for clarity of the output (especially if you have a long simulation - 1ns does not look as nice as 100 ns). The output plot will show the RMSD relative to the structure present in the original pdb file:

# %%
import pandas as pd
df = pd.read_csv('rmsd_xray.xvg', sep='\s+', header=None, names=['time','RMSD'])
df.plot('time')

# %% [markdown]
# Or for alterantive visualization, remove the comment characters (#) in the following cells:

# %%
#!printf "4\n1\n" | gmx rms -s em.tpr -f md_center.xtc -o rmsd_xray.xvg -tu ns

# %%
#!xmgrace rmsd_xray.xvg

# %% [markdown]
# The time series shows the RMSD levels off to ~0.15 nm (1.5 Å), indicating that the structure is stable.
#
# The option `-h` provides help information for GROMACS tool.

# %%
# !gmx rms -h

# %% [markdown]
# ## Radius of gyration

# %% [markdown]
# The radius of gyration of a protein is a measure of its compactness. If a protein is stably folded, it will likely maintain a relatively steady value of Rg. If a protein unfolds, its Rg will change over time. Let's analyze the radius of gyration for the protein in our simulation using GROMACS [`gmx gyrate`](https://manual.gromacs.org/current/onlinehelp/gmx-gyrate.html) tool:

# %%
# !echo "1" | gmx gyrate -f md_center.xtc -s md.tpr -o gyrate.xvg -xvg none

# %%
import pandas as pd
df = pd.read_csv('gyrate.xvg', sep='\s+', header=None, names=['time','Rg'], usecols=[0, 1])
df.plot('time')

# %% [markdown]
# Or for alterantive visualization, remove the comment characters (#) in the following cells:

# %%
#!echo "1" | gmx gyrate -f md_center.xtc -s md.tpr -o gyrate.xvg

# %%
#!xmgrace gyrate.xvg

# %% [markdown]
# We can see from the reasonably invariant Rg values that the protein remains very stable, in its compact (folded) form over the course of 1 ns at 300 K. This result is not unexpected, but illustrates an advanced capacity of GROMACS analysis that comes built-in.

# %% [markdown]
# ## Index file

# %% [markdown]
# Index groups are necessary for almost every GROMACS tools. All GROMACS tools can generate default index groups. If one needs special index groups, he/she can use gmx [gmx make_ndx](https://manual.gromacs.org/current/onlinehelp/gmx-make_ndx.html) to generate an index file (ndx). For example the command `splitch 1` splits the group 1 (Protein) in chains and the command `q`  close the tool.

# %%
# !printf "splitch 1\nq\n" | gmx make_ndx -f nvt.tpr -o

# %% [markdown]
# Now we can calculate the hydrogen bonds between the two protein chains using the tool [gmx hbond](https://manual.gromacs.org/current/onlinehelp/gmx-hbond.html). The option -num provide the number of hydrogen bond as a function of time.

# %%
# !printf "17\n18\n"| gmx hbond -f md.xtc -s md.tpr  -n index.ndx -num -xvg none

# %%
import pandas as pd
df = pd.read_csv('hbnum.xvg', sep='\s+', header=None, names=['time','H-bonds'], usecols=[0, 1])
df.plot('time')

# %% [markdown]
# Or for alterantive visualization, remove the comment characters (#) in the following cells:

# %%
#!printf "17\n18\n"| gmx hbond -f md.xtc -s md.tpr  -n index.ndx -num

# %%
#!xmgrace hbnum.xvg

# %% [markdown]
# ## Report time

# %% [markdown]
# Now that we have runned the simulation, we should report or recall about what type of simulation we have per
# formed. The GROMACS tool (`gmx report-methods`)[https://manual.gromacs.org/current/onlinehelp/gmx-report-methods.
# html] can be useful for this purpose. gmx report-methods print out basic system information on a performed run. It can also provide an unformatted text (with the option -o) or a LaTeX formatted output file with the option -m.
# Let's try it.

# %%
# !gmx report-methods -s md.tpr

# %% [markdown]
# ## Excursion: Plotting gromacs data with "pandas" in python and notebooks

# %% [markdown]
# To analyse or visualize simulation data in python or jupyter notebooks, we can output a simplified xvg format from gmx-analysis tools with the option `-xvg none`

# %%
# !echo "12\n0\n" | gmx energy -f em.edr -o potential.xvg -xvg none

# %% [markdown]
# And here is the plot..

# %%
import pandas as pd
df = pd.read_csv('potential.xvg', sep='\s+', header=None, names=['time','energy'])
df.plot('time')

# %%
# Starting a Rerun Simulation
# !gmx mdrun -s topol(.tpr) -rerun hvr060-040_pub.xtc
